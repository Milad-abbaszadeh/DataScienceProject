# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker
import matplotlib.ticker as plticker
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from datetime import datetime as dt
import itertools


from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm


from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense

from keras.utils import np_utils

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load the Dataset

# %%
df = pd.read_csv("../datasets/FIFA 1990-2018 - Cleaned.csv")
squads = pd.read_csv("../datasets/New_data/2018 FIFA World Cup Squads.csv")
fifa18 = pd.read_csv("../datasets/New_data/complete.csv")
distance = pd.read_csv("../datasets/New_data/distance.csv", error_bad_lines=False)
fifa_ranking = pd.read_csv("../datasets/New_data/fifa_ranking.csv")
# Out:
# b'Skipping line 31: expected 4 fields, saw 5\nSkipping line 63: expected 4 fields, saw 5\nSkipping line 85: expected 4 fields, saw 5\nSkipping line 102: expected 4 fields, saw 5\nSkipping line 173: expected 4 fields, saw 5\nSkipping line 174: expected 4 fields, saw 5\nSkipping line 196: expected 4 fields, saw 5\nSkipping line 203: expected 4 fields, saw 5\nSkipping line 204: expected 4 fields, saw 5\nSkipping line 207: expected 4 fields, saw 5\nSkipping line 211: expected 4 fields, saw 5\nSkipping line 213: expected 4 fields, saw 5\n'

# %%
df.head()
# Out:
#       Team1         Team2       Rounds                   Stadium  \
# 0    Russia  Saudi Arabia  Group Phase          Luzhniki Stadium
# 1     Egypt       Uruguay  Group Phase        Ekaterinburg Arena
# 2   Morocco       IR Iran  Group Phase  Saint Petersburg Stadium
# 3  Portugal         Spain  Group Phase             Fisht Stadium
# 4    France     Australia  Group Phase               Kazan Arena
#
#              City   Time  Day  Month  Year  Score1  Score2  \
# 0          Moscow  18:00   14      6  2018       5       0
# 1    Ekaterinburg  17:00   15      6  2018       0       1
# 2  St. Petersburg  18:00   15      6  2018       0       1
# 3           Sochi  21:00   15      6  2018       3       3
# 4           Kazan  13:00   16      6  2018       2       1
#
#                                              Remarks
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  {WinTeamName} win on aggregate after regular t...
# 4                                                NaN

# %% [markdown]
# # Select data for 2018

# %%
ranking_2018 = fifa_ranking[(fifa_ranking['rank_date']>"2018-04-01") & (fifa_ranking['rank_date']<"2018-05-01")]
df=df[df.Year == 2018]
ranking_2018.shape
# Out:
# (211, 17)

# %% [markdown]
# # change names

# %%
squads=squads.replace({"South Korea":"Korea Republic"})
squads=squads.replace({"Korea Republic":"Korea Republic"})
squads = squads.replace({"Iran":"IR Iran"})

# %% [markdown]
# # Duplicate

# %%
# we should change all respective column for duplicate
for index,row in df.iterrows():
    df.set_value(index+64,["Team1","Team2","Rounds","Stadium","City","Time","Day","Month","Year","Score1","Score2","Remarks"],[row["Team2"],row["Team1"],row["Rounds"],row['Stadium'],row['City'],row['Time'],row["Day"],row["Month"],row["Year"],row["Score2"],row["Score1"],row['Remarks']])
df.shape
# Out:
# /home/milad/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# (128, 12)

# %%
# Create new columns with ranking position of each team
df.insert(2, 'rank_Team1', df['Team1'].map(ranking_2018.set_index('country_full')['rank']))
df.insert(3, 'rank_Team2', df['Team2'].map(ranking_2018.set_index('country_full')['rank']))

df.insert(4, 'rank_change_Team1', df['Team1'].map(ranking_2018.set_index('country_full')['rank_change']))
df.insert(5, 'rank_change_Team2', df['Team2'].map(ranking_2018.set_index('country_full')['rank_change']))

# %%
df.head()
# Out:
#       Team1         Team2  rank_Team1  rank_Team2  rank_change_Team1  \
# 0    Russia  Saudi Arabia          66          70                 -3
# 1     Egypt       Uruguay          46          17                 -2
# 2   Morocco       IR Iran          42          36                  0
# 3  Portugal         Spain           4           8                 -1
# 4    France     Australia           7          40                  2
#
#    rank_change_Team2       Rounds                   Stadium            City  \
# 0                 -1  Group Phase          Luzhniki Stadium          Moscow
# 1                  5  Group Phase        Ekaterinburg Arena    Ekaterinburg
# 2                 -3  Group Phase  Saint Petersburg Stadium  St. Petersburg
# 3                 -2  Group Phase             Fisht Stadium           Sochi
# 4                 -3  Group Phase               Kazan Arena           Kazan
#
#     Time   Day  Month    Year  Score1  Score2  \
# 0  18:00  14.0    6.0  2018.0     5.0     0.0
# 1  17:00  15.0    6.0  2018.0     0.0     1.0
# 2  18:00  15.0    6.0  2018.0     0.0     1.0
# 3  21:00  15.0    6.0  2018.0     3.0     3.0
# 4  13:00  16.0    6.0  2018.0     2.0     1.0
#
#                                              Remarks
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  {WinTeamName} win on aggregate after regular t...
# 4                                                NaN

# %%
df.isnull().sum()
# Out:
# Team1                  0
# Team2                  0
# rank_Team1             0
# rank_Team2             0
# rank_change_Team1      0
# rank_change_Team2      0
# Rounds                 0
# Stadium                0
# City                   0
# Time                   0
# Day                    0
# Month                  0
# Year                   0
# Score1                 0
# Score2                 0
# Remarks              100
# dtype: int64

# %% [markdown]
# # Add Team features

# %%
# #AVG Age of each team in each position
age_avg=squads.groupby(["Team","Position"])['Age'].sum()/squads.groupby(["Team","Position"])['Age'].size()
age_avg = age_avg.to_frame()

age_avg['Team_name'] = age_avg.index.get_level_values(0).tolist()
age_avg['pos'] = age_avg.index.get_level_values(1).tolist()

# %%
age_DF = age_avg.loc[age_avg['pos'] == 'DF']
age_FW = age_avg.loc[age_avg['pos'] == 'FW']
age_GK = age_avg.loc[age_avg['pos'] == 'GK']
age_MF = age_avg.loc[age_avg['pos'] == 'MF']

# %%
df.head()
# Out:
#       Team1         Team2  rank_Team1  rank_Team2  rank_change_Team1  \
# 0    Russia  Saudi Arabia          66          70                 -3
# 1     Egypt       Uruguay          46          17                 -2
# 2   Morocco       IR Iran          42          36                  0
# 3  Portugal         Spain           4           8                 -1
# 4    France     Australia           7          40                  2
#
#    rank_change_Team2       Rounds                   Stadium            City  \
# 0                 -1  Group Phase          Luzhniki Stadium          Moscow
# 1                  5  Group Phase        Ekaterinburg Arena    Ekaterinburg
# 2                 -3  Group Phase  Saint Petersburg Stadium  St. Petersburg
# 3                 -2  Group Phase             Fisht Stadium           Sochi
# 4                 -3  Group Phase               Kazan Arena           Kazan
#
#     Time   Day  Month    Year  Score1  Score2  \
# 0  18:00  14.0    6.0  2018.0     5.0     0.0
# 1  17:00  15.0    6.0  2018.0     0.0     1.0
# 2  18:00  15.0    6.0  2018.0     0.0     1.0
# 3  21:00  15.0    6.0  2018.0     3.0     3.0
# 4  13:00  16.0    6.0  2018.0     2.0     1.0
#
#                                              Remarks
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  {WinTeamName} win on aggregate after regular t...
# 4                                                NaN

# %%
df.insert(2, 'Team1_avg_age_DF', df['Team1'].map(age_DF.set_index('Team_name')['Age']))
df.insert(3, 'Team1_avg_age_FW', df['Team1'].map(age_FW.set_index('Team_name')['Age']))
df.insert(4, 'Team1_avg_age_GK', df['Team1'].map(age_GK.set_index('Team_name')['Age']))
df.insert(5, 'Team1_avg_age_MF', df['Team1'].map(age_MF.set_index('Team_name')['Age']))

# %%
df.insert(6, 'Team2_avg_age_DF', df['Team2'].map(age_DF.set_index('Team_name')['Age']))
df.insert(7, 'Team2_avg_age_FW', df['Team2'].map(age_FW.set_index('Team_name')['Age']))
df.insert(8, 'Team2_avg_age_GK', df['Team2'].map(age_GK.set_index('Team_name')['Age']))
df.insert(9, 'Team2_avg_age_MF', df['Team2'].map(age_MF.set_index('Team_name')['Age']))

# %%
df.head()
# Out:
#       Team1         Team2  Team1_avg_age_DF  Team1_avg_age_FW  \
# 0    Russia  Saudi Arabia         29.857143         28.500000
# 1     Egypt       Uruguay         28.750000         25.833333
# 2   Morocco       IR Iran         27.000000         26.750000
# 3  Portugal         Spain         28.375000         26.600000
# 4    France     Australia         24.375000         24.142857
#
#    Team1_avg_age_GK  Team1_avg_age_MF  Team2_avg_age_DF  Team2_avg_age_FW  \
# 0         30.666667         26.545455         28.714286         28.333333
# 1         36.000000         26.833333         27.857143         27.666667
# 2         26.000000         26.900000         26.500000         26.428571
# 3         31.000000         27.000000         28.500000         28.800000
# 4         29.666667         27.000000         27.428571         26.625000
#
#    Team2_avg_age_GK  Team2_avg_age_MF  \
# 0         30.333333         27.000000
# 1         31.666667         25.714286
# 2         26.333333         27.400000
# 3         28.333333         26.714286
# 4         31.666667         27.000000
#
#                          ...                               Rounds  \
# 0                        ...                          Group Phase
# 1                        ...                          Group Phase
# 2                        ...                          Group Phase
# 3                        ...                          Group Phase
# 4                        ...                          Group Phase
#
#                     Stadium            City   Time   Day Month    Year Score1  \
# 0          Luzhniki Stadium          Moscow  18:00  14.0   6.0  2018.0    5.0
# 1        Ekaterinburg Arena    Ekaterinburg  17:00  15.0   6.0  2018.0    0.0
# 2  Saint Petersburg Stadium  St. Petersburg  18:00  15.0   6.0  2018.0    0.0
# 3             Fisht Stadium           Sochi  21:00  15.0   6.0  2018.0    3.0
# 4               Kazan Arena           Kazan  13:00  16.0   6.0  2018.0    2.0
#
#    Score2                                            Remarks
# 0     0.0                                                NaN
# 1     1.0                                                NaN
# 2     1.0                                                NaN
# 3     3.0  {WinTeamName} win on aggregate after regular t...
# 4     1.0                                                NaN
#
# [5 rows x 24 columns]

# %%
df.isnull().sum()
# Out:
# Team1                  0
# Team2                  0
# Team1_avg_age_DF       0
# Team1_avg_age_FW       0
# Team1_avg_age_GK       0
# Team1_avg_age_MF       0
# Team2_avg_age_DF       0
# Team2_avg_age_FW       0
# Team2_avg_age_GK       0
# Team2_avg_age_MF       0
# rank_Team1             0
# rank_Team2             0
# rank_change_Team1      0
# rank_change_Team2      0
# Rounds                 0
# Stadium                0
# City                   0
# Time                   0
# Day                    0
# Month                  0
# Year                   0
# Score1                 0
# Score2                 0
# Remarks              100
# dtype: int64

# %%
#AVG Caps of each team per position
caps_avg = squads.groupby(["Team","Position"])['Caps'].sum()/squads.groupby(["Team","Position"])['Caps'].size()
caps_avg = caps_avg.to_frame()

caps_avg['Team_name'] = caps_avg.index.get_level_values(0).tolist()
caps_avg['pos'] = caps_avg.index.get_level_values(1).tolist()

# %%
# caps_avg = caps_avg.replace({"Iran":"IR Iran"})
# caps_avg = caps_avg.replace({"Korea Republic":"South Korea"})
# caps_avg.head()

# %%
caps_DF = caps_avg.loc[age_avg['pos'] == 'DF']
caps_FW = caps_avg.loc[age_avg['pos'] == 'FW']
caps_GK = caps_avg.loc[age_avg['pos'] == 'GK']
caps_MF = caps_avg.loc[age_avg['pos'] == 'MF']

# %%
df.insert(10, 'Team1_avg_caps_DF', df['Team1'].map(caps_DF.set_index('Team_name')['Caps']))
df.insert(11, 'Team1_avg_caps_FW', df['Team1'].map(caps_FW.set_index('Team_name')['Caps']))
df.insert(12, 'Team1_avg_caps_GK', df['Team1'].map(caps_GK.set_index('Team_name')['Caps']))
df.insert(13, 'Team1_avg_caps_MF', df['Team1'].map(caps_MF.set_index('Team_name')['Caps']))

df.insert(14, 'Team2_avg_caps_DF', df['Team2'].map(caps_DF.set_index('Team_name')['Caps']))
df.insert(15, 'Team2_avg_caps_FW', df['Team2'].map(caps_FW.set_index('Team_name')['Caps']))
df.insert(16, 'Team2_avg_caps_GK', df['Team2'].map(caps_GK.set_index('Team_name')['Caps']))
df.insert(17, 'Team2_avg_caps_MF', df['Team2'].map(caps_MF.set_index('Team_name')['Caps']))

# %%
df.head()
# Out:
#       Team1         Team2  Team1_avg_age_DF  Team1_avg_age_FW  \
# 0    Russia  Saudi Arabia         29.857143         28.500000
# 1     Egypt       Uruguay         28.750000         25.833333
# 2   Morocco       IR Iran         27.000000         26.750000
# 3  Portugal         Spain         28.375000         26.600000
# 4    France     Australia         24.375000         24.142857
#
#    Team1_avg_age_GK  Team1_avg_age_MF  Team2_avg_age_DF  Team2_avg_age_FW  \
# 0         30.666667         26.545455         28.714286         28.333333
# 1         36.000000         26.833333         27.857143         27.666667
# 2         26.000000         26.900000         26.500000         26.428571
# 3         31.000000         27.000000         28.500000         28.800000
# 4         29.666667         27.000000         27.428571         26.625000
#
#    Team2_avg_age_GK  Team2_avg_age_MF  \
# 0         30.333333         27.000000
# 1         31.666667         25.714286
# 2         26.333333         27.400000
# 3         28.333333         26.714286
# 4         31.666667         27.000000
#
#                          ...                               Rounds  \
# 0                        ...                          Group Phase
# 1                        ...                          Group Phase
# 2                        ...                          Group Phase
# 3                        ...                          Group Phase
# 4                        ...                          Group Phase
#
#                     Stadium            City   Time   Day  Month    Year  \
# 0          Luzhniki Stadium          Moscow  18:00  14.0    6.0  2018.0
# 1        Ekaterinburg Arena    Ekaterinburg  17:00  15.0    6.0  2018.0
# 2  Saint Petersburg Stadium  St. Petersburg  18:00  15.0    6.0  2018.0
# 3             Fisht Stadium           Sochi  21:00  15.0    6.0  2018.0
# 4               Kazan Arena           Kazan  13:00  16.0    6.0  2018.0
#
#    Score1  Score2                                            Remarks
# 0     5.0     0.0                                                NaN
# 1     0.0     1.0                                                NaN
# 2     0.0     1.0                                                NaN
# 3     3.0     3.0  {WinTeamName} win on aggregate after regular t...
# 4     2.0     1.0                                                NaN
#
# [5 rows x 32 columns]

# %%
df.isnull().sum()
# Out:
# Team1                  0
# Team2                  0
# Team1_avg_age_DF       0
# Team1_avg_age_FW       0
# Team1_avg_age_GK       0
# Team1_avg_age_MF       0
# Team2_avg_age_DF       0
# Team2_avg_age_FW       0
# Team2_avg_age_GK       0
# Team2_avg_age_MF       0
# Team1_avg_caps_DF      0
# Team1_avg_caps_FW      0
# Team1_avg_caps_GK      0
# Team1_avg_caps_MF      0
# Team2_avg_caps_DF      0
# Team2_avg_caps_FW      0
# Team2_avg_caps_GK      0
# Team2_avg_caps_MF      0
# rank_Team1             0
# rank_Team2             0
# rank_change_Team1      0
# rank_change_Team2      0
# Rounds                 0
# Stadium                0
# City                   0
# Time                   0
# Day                    0
# Month                  0
# Year                   0
# Score1                 0
# Score2                 0
# Remarks              100
# dtype: int64

# %% [markdown]
# # change Rounds

# %%
rounds = df.Rounds
rounds.unique()
rounds_dict = {"Group Phase":1, "Round of 16":2, "Quarter Finals":3, "Semi Finals":4, "Play-off for third place":5, "Finals":6}
rounds_encoded = []

for i in range(len(df)):
    rounds_encoded.append(rounds_dict[list(df.Rounds)[i]])
    
df["Rounds"] = rounds_encoded

# %%
df.head()
# Out:
#       Team1         Team2  Team1_avg_age_DF  Team1_avg_age_FW  \
# 0    Russia  Saudi Arabia         29.857143         28.500000
# 1     Egypt       Uruguay         28.750000         25.833333
# 2   Morocco       IR Iran         27.000000         26.750000
# 3  Portugal         Spain         28.375000         26.600000
# 4    France     Australia         24.375000         24.142857
#
#    Team1_avg_age_GK  Team1_avg_age_MF  Team2_avg_age_DF  Team2_avg_age_FW  \
# 0         30.666667         26.545455         28.714286         28.333333
# 1         36.000000         26.833333         27.857143         27.666667
# 2         26.000000         26.900000         26.500000         26.428571
# 3         31.000000         27.000000         28.500000         28.800000
# 4         29.666667         27.000000         27.428571         26.625000
#
#    Team2_avg_age_GK  Team2_avg_age_MF  \
# 0         30.333333         27.000000
# 1         31.666667         25.714286
# 2         26.333333         27.400000
# 3         28.333333         26.714286
# 4         31.666667         27.000000
#
#                          ...                          Rounds  \
# 0                        ...                               1
# 1                        ...                               1
# 2                        ...                               1
# 3                        ...                               1
# 4                        ...                               1
#
#                     Stadium            City   Time   Day  Month    Year  \
# 0          Luzhniki Stadium          Moscow  18:00  14.0    6.0  2018.0
# 1        Ekaterinburg Arena    Ekaterinburg  17:00  15.0    6.0  2018.0
# 2  Saint Petersburg Stadium  St. Petersburg  18:00  15.0    6.0  2018.0
# 3             Fisht Stadium           Sochi  21:00  15.0    6.0  2018.0
# 4               Kazan Arena           Kazan  13:00  16.0    6.0  2018.0
#
#    Score1  Score2                                            Remarks
# 0     5.0     0.0                                                NaN
# 1     0.0     1.0                                                NaN
# 2     0.0     1.0                                                NaN
# 3     3.0     3.0  {WinTeamName} win on aggregate after regular t...
# 4     2.0     1.0                                                NaN
#
# [5 rows x 32 columns]

# %% [markdown]
# # Player Features

# %%
# fifa18 = fifa18.replace({"South Korea":"Korea Republic"})
wc_player_stats_18 = fifa18[fifa18["name"].isin(squads.Player) | fifa18["full_name"].isin(squads.Player)]
wc_fifa18_stats = fifa18[fifa18.nationality.isin(squads.Team)]

# %%
wc_fifa18_stats.replace([False,"False",True,"True"],[0,0,1,1])
unused_var=[]
for i in fifa18.columns:
    if "prefers" in i:
        unused_var.append(i)
wc_fifa18_stats = wc_fifa18_stats.drop(["club_logo","ID","real_face","birth_date","flag","photo"],axis=1)
wc_fifa18_stats = wc_fifa18_stats.drop(unused_var,axis=1)
grouped_wc_fifa18_stats = wc_fifa18_stats.groupby(['nationality']).apply(lambda x: (x.sort_values('overall',ascending=False)).head(30).mean()).sort_values('potential',ascending=True)
grouped_wc_fifa18_stats.head()
# Out:
#                  special        age   height_cm  weight_kg     eur_value  \
# nationality
# Panama       1617.375000  25.812500  181.750000  76.500000  8.378125e+05
# Tunisia      1677.966667  27.266667  182.700000  76.666667  2.261167e+06
# Costa Rica   1695.966667  26.433333  181.000000  75.400000  3.196167e+06
# Iceland      1771.000000  27.233333  184.066667  78.200000  2.607500e+06
# Peru         1651.965517  25.517241  178.931034  73.896552  2.122069e+06
#
#                  eur_wage  eur_release_clause    overall  potential  \
# nationality
# Panama        3312.500000        1.344812e+06  65.812500  69.437500
# Tunisia      11700.000000        2.739000e+06  68.966667  71.533333
# Costa Rica   18033.333333        5.612536e+06  69.900000  72.000000
# Iceland      16700.000000        4.797357e+06  70.033333  72.166667
# Peru          6620.689655        5.940867e+06  69.137931  72.689655
#
#                    pac              ...               playmaker_speciality  \
# nationality                         ...
# Panama       66.062500              ...                                0.0
# Tunisia      66.200000              ...                                0.0
# Costa Rica   73.400000              ...                                0.0
# Iceland      67.766667              ...                                0.0
# Peru         69.551724              ...                                0.0
#
#              engine_speciality  distance_shooter_speciality  \
# nationality
# Panama                     0.0                          0.0
# Tunisia                    0.0                          0.0
# Costa Rica                 0.0                          0.0
# Iceland                    0.1                          0.0
# Peru                       0.0                          0.0
#
#              crosser_speciality  free_kick_specialist_speciality  \
# nationality
# Panama                 0.000000                         0.000000
# Tunisia                0.000000                         0.000000
# Costa Rica             0.000000                         0.000000
# Iceland                0.033333                         0.033333
# Peru                   0.000000                         0.000000
#
#              tackling_speciality  tactician_speciality  acrobat_speciality  \
# nationality
# Panama                       0.0                   0.0            0.000000
# Tunisia                      0.0                   0.0            0.000000
# Costa Rica                   0.0                   0.0            0.000000
# Iceland                      0.0                   0.0            0.000000
# Peru                         0.0                   0.0            0.034483
#
#              strength_speciality  clinical_finisher_speciality
# nationality
# Panama                  0.062500                           0.0
# Tunisia                 0.033333                           0.0
# Costa Rica              0.066667                           0.0
# Iceland                 0.000000                           0.0
# Peru                    0.000000                           0.0
#
# [5 rows x 143 columns]

# %%
grouped_wc_fifa18_stats['Team_name'] = grouped_wc_fifa18_stats.index.get_level_values(0).tolist()

# %%
grouped_wc_fifa18_stats = grouped_wc_fifa18_stats.replace({"Iran":"IR Iran"})
grouped_wc_fifa18_stats = grouped_wc_fifa18_stats.replace({"South Korea":"Korea Republic"})
# grouped_wc_fifa18_stats.head()

# %%
df.isnull().sum()
# Out:
# Team1                  0
# Team2                  0
# Team1_avg_age_DF       0
# Team1_avg_age_FW       0
# Team1_avg_age_GK       0
# Team1_avg_age_MF       0
# Team2_avg_age_DF       0
# Team2_avg_age_FW       0
# Team2_avg_age_GK       0
# Team2_avg_age_MF       0
# Team1_avg_caps_DF      0
# Team1_avg_caps_FW      0
# Team1_avg_caps_GK      0
# Team1_avg_caps_MF      0
# Team2_avg_caps_DF      0
# Team2_avg_caps_FW      0
# Team2_avg_caps_GK      0
# Team2_avg_caps_MF      0
# rank_Team1             0
# rank_Team2             0
# rank_change_Team1      0
# rank_change_Team2      0
# Rounds                 0
# Stadium                0
# City                   0
# Time                   0
# Day                    0
# Month                  0
# Year                   0
# Score1                 0
# Score2                 0
# Remarks              100
# dtype: int64

# %%
for key in grouped_wc_fifa18_stats.keys():
    if key != 'Team_name':
        df.insert(12, 'Team2_'+key, df['Team2'].map(grouped_wc_fifa18_stats.set_index('Team_name')[key]))
        df.insert(12, 'Team1_'+key, df['Team1'].map(grouped_wc_fifa18_stats.set_index('Team_name')[key]))

# %%
df.head()
# Out:
#       Team1         Team2  Team1_avg_age_DF  Team1_avg_age_FW  \
# 0    Russia  Saudi Arabia         29.857143         28.500000
# 1     Egypt       Uruguay         28.750000         25.833333
# 2   Morocco       IR Iran         27.000000         26.750000
# 3  Portugal         Spain         28.375000         26.600000
# 4    France     Australia         24.375000         24.142857
#
#    Team1_avg_age_GK  Team1_avg_age_MF  Team2_avg_age_DF  Team2_avg_age_FW  \
# 0         30.666667         26.545455         28.714286         28.333333
# 1         36.000000         26.833333         27.857143         27.666667
# 2         26.000000         26.900000         26.500000         26.428571
# 3         31.000000         27.000000         28.500000         28.800000
# 4         29.666667         27.000000         27.428571         26.625000
#
#    Team2_avg_age_GK  Team2_avg_age_MF  \
# 0         30.333333         27.000000
# 1         31.666667         25.714286
# 2         26.333333         27.400000
# 3         28.333333         26.714286
# 4         31.666667         27.000000
#
#                          ...                          Rounds  \
# 0                        ...                               1
# 1                        ...                               1
# 2                        ...                               1
# 3                        ...                               1
# 4                        ...                               1
#
#                     Stadium            City   Time   Day  Month    Year  \
# 0          Luzhniki Stadium          Moscow  18:00  14.0    6.0  2018.0
# 1        Ekaterinburg Arena    Ekaterinburg  17:00  15.0    6.0  2018.0
# 2  Saint Petersburg Stadium  St. Petersburg  18:00  15.0    6.0  2018.0
# 3             Fisht Stadium           Sochi  21:00  15.0    6.0  2018.0
# 4               Kazan Arena           Kazan  13:00  16.0    6.0  2018.0
#
#    Score1  Score2                                            Remarks
# 0     5.0     0.0                                                NaN
# 1     0.0     1.0                                                NaN
# 2     0.0     1.0                                                NaN
# 3     3.0     3.0  {WinTeamName} win on aggregate after regular t...
# 4     2.0     1.0                                                NaN
#
# [5 rows x 318 columns]

# %%
df.isnull().sum()
# Out:
# Team1                                      0
# Team2                                      0
# Team1_avg_age_DF                           0
# Team1_avg_age_FW                           0
# Team1_avg_age_GK                           0
# Team1_avg_age_MF                           0
# Team2_avg_age_DF                           0
# Team2_avg_age_FW                           0
# Team2_avg_age_GK                           0
# Team2_avg_age_MF                           0
# Team1_avg_caps_DF                          0
# Team1_avg_caps_FW                          0
# Team1_clinical_finisher_speciality         3
# Team2_clinical_finisher_speciality         3
# Team1_strength_speciality                  3
# Team2_strength_speciality                  3
# Team1_acrobat_speciality                   3
# Team2_acrobat_speciality                   3
# Team1_tactician_speciality                 3
# Team2_tactician_speciality                 3
# Team1_tackling_speciality                  3
# Team2_tackling_speciality                  3
# Team1_free_kick_specialist_speciality      3
# Team2_free_kick_specialist_speciality      3
# Team1_crosser_speciality                   3
# Team2_crosser_speciality                   3
# Team1_distance_shooter_speciality          3
# Team2_distance_shooter_speciality          3
# Team1_engine_speciality                    3
# Team2_engine_speciality                    3
#                                         ...
# Team1_eur_value                            3
# Team2_eur_value                            3
# Team1_weight_kg                            3
# Team2_weight_kg                            3
# Team1_height_cm                            3
# Team2_height_cm                            3
# Team1_age                                  3
# Team2_age                                  3
# Team1_special                              3
# Team2_special                              3
# Team1_avg_caps_GK                          0
# Team1_avg_caps_MF                          0
# Team2_avg_caps_DF                          0
# Team2_avg_caps_FW                          0
# Team2_avg_caps_GK                          0
# Team2_avg_caps_MF                          0
# rank_Team1                                 0
# rank_Team2                                 0
# rank_change_Team1                          0
# rank_change_Team2                          0
# Rounds                                     0
# Stadium                                    0
# City                                       0
# Time                                       0
# Day                                        0
# Month                                      0
# Year                                       0
# Score1                                     0
# Score2                                     0
# Remarks                                  100
# Length: 318, dtype: int64

# %% [markdown]
# # code country name

# %%
countries = list(set(df["Team1"]).union(set(df["Team2"])))
countries_dict = {}
for i in range(len(countries)):
    countries_dict[countries[i]] = i
    
Team1_encoded = []
Team2_encoded = []

for i in range(len(df)):
    Team1_encoded.append(countries_dict[list(df.Team1)[i]])
    Team2_encoded.append(countries_dict[list(df.Team2)[i]])
    
df["Team1"] = Team1_encoded
df["Team2"] = Team2_encoded

# %%
#Adding who is the winner 
winner = []
for i in range (len(df['Team1'])):
    if df['Score1'][i] > df['Score2'][i]:
        winner.append(df['Team1'][i])
    elif df['Score1'][i] < df['Score2'][i]:
        winner.append(df['Team2'][i])
    else:
        winner.append(-1)
df['winning_team'] = winner

df.head()
# Out:
#    Team1  Team2  Team1_avg_age_DF  Team1_avg_age_FW  Team1_avg_age_GK  \
# 0     20      4         29.857143         28.500000         30.666667
# 1      3      9         28.750000         25.833333         36.000000
# 2     23     12         27.000000         26.750000         26.000000
# 3     31     11         28.375000         26.600000         31.000000
# 4     15     10         24.375000         24.142857         29.666667
#
#    Team1_avg_age_MF  Team2_avg_age_DF  Team2_avg_age_FW  Team2_avg_age_GK  \
# 0         26.545455         28.714286         28.333333         30.333333
# 1         26.833333         27.857143         27.666667         31.666667
# 2         26.900000         26.500000         26.428571         26.333333
# 3         27.000000         28.500000         28.800000         28.333333
# 4         27.000000         27.428571         26.625000         31.666667
#
#    Team2_avg_age_MF      ...                        Stadium            City  \
# 0         27.000000      ...               Luzhniki Stadium          Moscow
# 1         25.714286      ...             Ekaterinburg Arena    Ekaterinburg
# 2         27.400000      ...       Saint Petersburg Stadium  St. Petersburg
# 3         26.714286      ...                  Fisht Stadium           Sochi
# 4         27.000000      ...                    Kazan Arena           Kazan
#
#     Time   Day  Month    Year  Score1  Score2  \
# 0  18:00  14.0    6.0  2018.0     5.0     0.0
# 1  17:00  15.0    6.0  2018.0     0.0     1.0
# 2  18:00  15.0    6.0  2018.0     0.0     1.0
# 3  21:00  15.0    6.0  2018.0     3.0     3.0
# 4  13:00  16.0    6.0  2018.0     2.0     1.0
#
#                                              Remarks  winning_team
# 0                                                NaN            20
# 1                                                NaN             9
# 2                                                NaN            12
# 3  {WinTeamName} win on aggregate after regular t...            -1
# 4                                                NaN            15
#
# [5 rows x 319 columns]

# %%
df = df.drop(['Score1','Score2','Remarks',"Stadium","City"],axis=1)
df.head()
# Out:
#    Team1  Team2  Team1_avg_age_DF  Team1_avg_age_FW  Team1_avg_age_GK  \
# 0     20      4         29.857143         28.500000         30.666667
# 1      3      9         28.750000         25.833333         36.000000
# 2     23     12         27.000000         26.750000         26.000000
# 3     31     11         28.375000         26.600000         31.000000
# 4     15     10         24.375000         24.142857         29.666667
#
#    Team1_avg_age_MF  Team2_avg_age_DF  Team2_avg_age_FW  Team2_avg_age_GK  \
# 0         26.545455         28.714286         28.333333         30.333333
# 1         26.833333         27.857143         27.666667         31.666667
# 2         26.900000         26.500000         26.428571         26.333333
# 3         27.000000         28.500000         28.800000         28.333333
# 4         27.000000         27.428571         26.625000         31.666667
#
#    Team2_avg_age_MF      ...       rank_Team1  rank_Team2  rank_change_Team1  \
# 0         27.000000      ...               66          70                 -3
# 1         25.714286      ...               46          17                 -2
# 2         27.400000      ...               42          36                  0
# 3         26.714286      ...                4           8                 -1
# 4         27.000000      ...                7          40                  2
#
#    rank_change_Team2  Rounds   Time   Day  Month    Year  winning_team
# 0                 -1       1  18:00  14.0    6.0  2018.0            20
# 1                  5       1  17:00  15.0    6.0  2018.0             9
# 2                 -3       1  18:00  15.0    6.0  2018.0            12
# 3                 -2       1  21:00  15.0    6.0  2018.0            -1
# 4                 -3       1  13:00  16.0    6.0  2018.0            15
#
# [5 rows x 314 columns]

# %%
df.isnull().sum()
# Out:
# Team1                                    0
# Team2                                    0
# Team1_avg_age_DF                         0
# Team1_avg_age_FW                         0
# Team1_avg_age_GK                         0
# Team1_avg_age_MF                         0
# Team2_avg_age_DF                         0
# Team2_avg_age_FW                         0
# Team2_avg_age_GK                         0
# Team2_avg_age_MF                         0
# Team1_avg_caps_DF                        0
# Team1_avg_caps_FW                        0
# Team1_clinical_finisher_speciality       3
# Team2_clinical_finisher_speciality       3
# Team1_strength_speciality                3
# Team2_strength_speciality                3
# Team1_acrobat_speciality                 3
# Team2_acrobat_speciality                 3
# Team1_tactician_speciality               3
# Team2_tactician_speciality               3
# Team1_tackling_speciality                3
# Team2_tackling_speciality                3
# Team1_free_kick_specialist_speciality    3
# Team2_free_kick_specialist_speciality    3
# Team1_crosser_speciality                 3
# Team2_crosser_speciality                 3
# Team1_distance_shooter_speciality        3
# Team2_distance_shooter_speciality        3
# Team1_engine_speciality                  3
# Team2_engine_speciality                  3
#                                         ..
# Team1_eur_release_clause                 3
# Team2_eur_release_clause                 3
# Team1_eur_wage                           3
# Team2_eur_wage                           3
# Team1_eur_value                          3
# Team2_eur_value                          3
# Team1_weight_kg                          3
# Team2_weight_kg                          3
# Team1_height_cm                          3
# Team2_height_cm                          3
# Team1_age                                3
# Team2_age                                3
# Team1_special                            3
# Team2_special                            3
# Team1_avg_caps_GK                        0
# Team1_avg_caps_MF                        0
# Team2_avg_caps_DF                        0
# Team2_avg_caps_FW                        0
# Team2_avg_caps_GK                        0
# Team2_avg_caps_MF                        0
# rank_Team1                               0
# rank_Team2                               0
# rank_change_Team1                        0
# rank_change_Team2                        0
# Rounds                                   0
# Time                                     0
# Day                                      0
# Month                                    0
# Year                                     0
# winning_team                             0
# Length: 314, dtype: int64

# %%
df = df.fillna(0)

# %%
for c in df.keys():
    print(c)
# Out:
# Team1
# Team2
# Team1_avg_age_DF
# Team1_avg_age_FW
# Team1_avg_age_GK
# Team1_avg_age_MF
# Team2_avg_age_DF
# Team2_avg_age_FW
# Team2_avg_age_GK
# Team2_avg_age_MF
# Team1_avg_caps_DF
# Team1_avg_caps_FW
# Team1_clinical_finisher_speciality
# Team2_clinical_finisher_speciality
# Team1_strength_speciality
# Team2_strength_speciality
# Team1_acrobat_speciality
# Team2_acrobat_speciality
# Team1_tactician_speciality
# Team2_tactician_speciality
# Team1_tackling_speciality
# Team2_tackling_speciality
# Team1_free_kick_specialist_speciality
# Team2_free_kick_specialist_speciality
# Team1_crosser_speciality
# Team2_crosser_speciality
# Team1_distance_shooter_speciality
# Team2_distance_shooter_speciality
# Team1_engine_speciality
# Team2_engine_speciality
# Team1_playmaker_speciality
# Team2_playmaker_speciality
# Team1_dribbler_speciality
# Team2_dribbler_speciality
# Team1_aerial_threat_speciality
# Team2_aerial_threat_speciality
# Team1_speedster_speciality
# Team2_speedster_speciality
# Team1_poacher_speciality
# Team2_poacher_speciality
# Team1_tries_to_beat_defensive_line_trait
# Team2_tries_to_beat_defensive_line_trait
# Team1_technical_dribbler_trait
# Team2_technical_dribbler_trait
# Team1_team_player_trait
# Team2_team_player_trait
# Team1_target_forward_trait
# Team2_target_forward_trait
# Team1_takes_finesse_free_kicks_trait
# Team2_takes_finesse_free_kicks_trait
# Team1_swerve_pass_trait
# Team2_swerve_pass_trait
# Team1_stutter_penalty_trait
# Team2_stutter_penalty_trait
# Team1_skilled_dribbling_trait
# Team2_skilled_dribbling_trait
# Team1_selfish_trait
# Team2_selfish_trait
# Team1_second_wind_trait
# Team2_second_wind_trait
# Team1_saves_with_feet_trait
# Team2_saves_with_feet_trait
# Team1_rushes_out_of_goal_trait
# Team2_rushes_out_of_goal_trait
# Team1_puncher_trait
# Team2_puncher_trait
# Team1_power_header_trait
# Team2_power_header_trait
# Team1_power_free_kick_trait
# Team2_power_free_kick_trait
# Team1_playmaker_trait
# Team2_playmaker_trait
# Team1_outside_foot_shot_trait
# Team2_outside_foot_shot_trait
# Team1_one_club_player_trait
# Team2_one_club_player_trait
# Team1_long_throw_in_trait
# Team2_long_throw_in_trait
# Team1_long_shot_taker_trait
# Team2_long_shot_taker_trait
# Team1_long_passer_trait
# Team2_long_passer_trait
# Team1_leadership_trait
# Team2_leadership_trait
# Team1_injury_prone_trait
# Team2_injury_prone_trait
# Team1_injury_free_trait
# Team2_injury_free_trait
# Team1_inflexible_trait
# Team2_inflexible_trait
# Team1_giant_throw_in_trait
# Team2_giant_throw_in_trait
# Team1_gk_up_for_corners_trait
# Team2_gk_up_for_corners_trait
# Team1_gk_long_throw_trait
# Team2_gk_long_throw_trait
# Team1_gk_flat_kick_trait
# Team2_gk_flat_kick_trait
# Team1_flair_passes_trait
# Team2_flair_passes_trait
# Team1_flair_trait
# Team2_flair_trait
# Team1_finesse_shot_trait
# Team2_finesse_shot_trait
# Team1_fancy_flicks_trait
# Team2_fancy_flicks_trait
# Team1_fan's_favourite_trait
# Team2_fan's_favourite_trait
# Team1_early_crosser_trait
# Team2_early_crosser_trait
# Team1_driven_pass_trait
# Team2_driven_pass_trait
# Team1_diving_header_trait
# Team2_diving_header_trait
# Team1_dives_into_tackles_trait
# Team2_dives_into_tackles_trait
# Team1_diver_trait
# Team2_diver_trait
# Team1_corner_specialist_trait
# Team2_corner_specialist_trait
# Team1_comes_for_crosses_trait
# Team2_comes_for_crosses_trait
# Team1_chipped_penalty_trait
# Team2_chipped_penalty_trait
# Team1_chip_shot_trait
# Team2_chip_shot_trait
# Team1_cautious_with_crosses_trait
# Team2_cautious_with_crosses_trait
# Team1_bicycle_kicks_trait
# Team2_bicycle_kicks_trait
# Team1_backs_into_player_trait
# Team2_backs_into_player_trait
# Team1_avoids_using_weaker_foot_trait
# Team2_avoids_using_weaker_foot_trait
# Team1_argues_with_officials_trait
# Team2_argues_with_officials_trait
# Team1_acrobatic_clearance_trait
# Team2_acrobatic_clearance_trait
# Team1_1_on_1_rush_trait
# Team2_1_on_1_rush_trait
# Team1_gk
# Team2_gk
# Team1_lcb
# Team2_lcb
# Team1_ldm
# Team2_ldm
# Team1_lcm
# Team2_lcm
# Team1_lam
# Team2_lam
# Team1_lf
# Team2_lf
# Team1_ls
# Team2_ls
# Team1_lwb
# Team2_lwb
# Team1_lb
# Team2_lb
# Team1_cb
# Team2_cb
# Team1_cdm
# Team2_cdm
# Team1_lm
# Team2_lm
# Team1_cm
# Team2_cm
# Team1_cam
# Team2_cam
# Team1_cf
# Team2_cf
# Team1_lw
# Team2_lw
# Team1_st
# Team2_st
# Team1_rwb
# Team2_rwb
# Team1_rb
# Team2_rb
# Team1_rcb
# Team2_rcb
# Team1_rdm
# Team2_rdm
# Team1_rm
# Team2_rm
# Team1_rcm
# Team2_rcm
# Team1_ram
# Team2_ram
# Team1_rf
# Team2_rf
# Team1_rw
# Team2_rw
# Team1_rs
# Team2_rs
# Team1_gk_reflexes
# Team2_gk_reflexes
# Team1_gk_positioning
# Team2_gk_positioning
# Team1_gk_kicking
# Team2_gk_kicking
# Team1_gk_handling
# Team2_gk_handling
# Team1_gk_diving
# Team2_gk_diving
# Team1_sliding_tackle
# Team2_sliding_tackle
# Team1_standing_tackle
# Team2_standing_tackle
# Team1_marking
# Team2_marking
# Team1_composure
# Team2_composure
# Team1_penalties
# Team2_penalties
# Team1_vision
# Team2_vision
# Team1_positioning
# Team2_positioning
# Team1_interceptions
# Team2_interceptions
# Team1_aggression
# Team2_aggression
# Team1_long_shots
# Team2_long_shots
# Team1_strength
# Team2_strength
# Team1_stamina
# Team2_stamina
# Team1_jumping
# Team2_jumping
# Team1_shot_power
# Team2_shot_power
# Team1_balance
# Team2_balance
# Team1_reactions
# Team2_reactions
# Team1_agility
# Team2_agility
# Team1_sprint_speed
# Team2_sprint_speed
# Team1_acceleration
# Team2_acceleration
# Team1_ball_control
# Team2_ball_control
# Team1_long_passing
# Team2_long_passing
# Team1_free_kick_accuracy
# Team2_free_kick_accuracy
# Team1_curve
# Team2_curve
# Team1_dribbling
# Team2_dribbling
# Team1_volleys
# Team2_volleys
# Team1_short_passing
# Team2_short_passing
# Team1_heading_accuracy
# Team2_heading_accuracy
# Team1_finishing
# Team2_finishing
# Team1_crossing
# Team2_crossing
# Team1_weak_foot
# Team2_weak_foot
# Team1_skill_moves
# Team2_skill_moves
# Team1_international_reputation
# Team2_international_reputation
# Team1_phy
# Team2_phy
# Team1_def
# Team2_def
# Team1_dri
# Team2_dri
# Team1_pas
# Team2_pas
# Team1_sho
# Team2_sho
# Team1_pac
# Team2_pac
# Team1_potential
# Team2_potential
# Team1_overall
# Team2_overall
# Team1_eur_release_clause
# Team2_eur_release_clause
# Team1_eur_wage
# Team2_eur_wage
# Team1_eur_value
# Team2_eur_value
# Team1_weight_kg
# Team2_weight_kg
# Team1_height_cm
# Team2_height_cm
# Team1_age
# Team2_age
# Team1_special
# Team2_special
# Team1_avg_caps_GK
# Team1_avg_caps_MF
# Team2_avg_caps_DF
# Team2_avg_caps_FW
# Team2_avg_caps_GK
# Team2_avg_caps_MF
# rank_Team1
# rank_Team2
# rank_change_Team1
# rank_change_Team2
# Rounds
# Time
# Day
# Month
# Year
# winning_team

# %%
df.shape
# Out:
# (128, 314)

# %%
df.head()
# Out:
#    Team1  Team2  Team1_avg_age_DF  Team1_avg_age_FW  Team1_avg_age_GK  \
# 0     20      4         29.857143         28.500000         30.666667
# 1      3      9         28.750000         25.833333         36.000000
# 2     23     12         27.000000         26.750000         26.000000
# 3     31     11         28.375000         26.600000         31.000000
# 4     15     10         24.375000         24.142857         29.666667
#
#    Team1_avg_age_MF  Team2_avg_age_DF  Team2_avg_age_FW  Team2_avg_age_GK  \
# 0         26.545455         28.714286         28.333333         30.333333
# 1         26.833333         27.857143         27.666667         31.666667
# 2         26.900000         26.500000         26.428571         26.333333
# 3         27.000000         28.500000         28.800000         28.333333
# 4         27.000000         27.428571         26.625000         31.666667
#
#    Team2_avg_age_MF      ...       rank_Team1  rank_Team2  rank_change_Team1  \
# 0         27.000000      ...               66          70                 -3
# 1         25.714286      ...               46          17                 -2
# 2         27.400000      ...               42          36                  0
# 3         26.714286      ...                4           8                 -1
# 4         27.000000      ...                7          40                  2
#
#    rank_change_Team2  Rounds   Time   Day  Month    Year  winning_team
# 0                 -1       1  18:00  14.0    6.0  2018.0            20
# 1                  5       1  17:00  15.0    6.0  2018.0             9
# 2                 -3       1  18:00  15.0    6.0  2018.0            12
# 3                 -2       1  21:00  15.0    6.0  2018.0            -1
# 4                 -3       1  13:00  16.0    6.0  2018.0            15
#
# [5 rows x 314 columns]

# %% [markdown]
# # Duplicate

# %%
df.loc[0,:]
# Out:
# Team1                                             20
# Team2                                              4
# Team1_avg_age_DF                             29.8571
# Team1_avg_age_FW                                28.5
# Team1_avg_age_GK                             30.6667
# Team1_avg_age_MF                             26.5455
# Team2_avg_age_DF                             28.7143
# Team2_avg_age_FW                             28.3333
# Team2_avg_age_GK                             30.3333
# Team2_avg_age_MF                                  27
# Team1_avg_caps_DF                            27.5714
# Team1_avg_caps_FW                                 27
# Team1_clinical_finisher_speciality                 0
# Team2_clinical_finisher_speciality                 0
# Team1_strength_speciality                  0.0666667
# Team2_strength_speciality                  0.0333333
# Team1_acrobat_speciality                           0
# Team2_acrobat_speciality                   0.0333333
# Team1_tactician_speciality                         0
# Team2_tactician_speciality                         0
# Team1_tackling_speciality                          0
# Team2_tackling_speciality                          0
# Team1_free_kick_specialist_speciality              0
# Team2_free_kick_specialist_speciality              0
# Team1_crosser_speciality                           0
# Team2_crosser_speciality                           0
# Team1_distance_shooter_speciality                  0
# Team2_distance_shooter_speciality                  0
# Team1_engine_speciality                    0.0333333
# Team2_engine_speciality                    0.0333333
#                                             ...
# Team1_eur_release_clause                 1.38667e+07
# Team2_eur_release_clause                    5.63e+06
# Team1_eur_wage                               47433.3
# Team2_eur_wage                                 26800
# Team1_eur_value                          8.73667e+06
# Team2_eur_value                          3.19667e+06
# Team1_weight_kg                              79.0667
# Team2_weight_kg                              68.1333
# Team1_height_cm                              184.867
# Team2_height_cm                              174.333
# Team1_age                                    28.8333
# Team2_age                                    27.7333
# Team1_special                                 1748.3
# Team2_special                                1746.17
# Team1_avg_caps_GK                            39.3333
# Team1_avg_caps_MF                                 25
# Team2_avg_caps_DF                                 40
# Team2_avg_caps_FW                            33.6667
# Team2_avg_caps_GK                                 16
# Team2_avg_caps_MF                               34.3
# rank_Team1                                        66
# rank_Team2                                        70
# rank_change_Team1                                 -3
# rank_change_Team2                                 -1
# Rounds                                             1
# Time                                           18:00
# Day                                               14
# Month                                              6
# Year                                            2018
# winning_team                                      20
# Name: 0, Length: 314, dtype: object

# %%
df.loc[64,:]
# Out:
# Team1                                              4
# Team2                                             20
# Team1_avg_age_DF                             28.7143
# Team1_avg_age_FW                             28.3333
# Team1_avg_age_GK                             30.3333
# Team1_avg_age_MF                                  27
# Team2_avg_age_DF                             29.8571
# Team2_avg_age_FW                                28.5
# Team2_avg_age_GK                             30.6667
# Team2_avg_age_MF                             26.5455
# Team1_avg_caps_DF                                 40
# Team1_avg_caps_FW                            33.6667
# Team1_clinical_finisher_speciality                 0
# Team2_clinical_finisher_speciality                 0
# Team1_strength_speciality                  0.0333333
# Team2_strength_speciality                  0.0666667
# Team1_acrobat_speciality                   0.0333333
# Team2_acrobat_speciality                           0
# Team1_tactician_speciality                         0
# Team2_tactician_speciality                         0
# Team1_tackling_speciality                          0
# Team2_tackling_speciality                          0
# Team1_free_kick_specialist_speciality              0
# Team2_free_kick_specialist_speciality              0
# Team1_crosser_speciality                           0
# Team2_crosser_speciality                           0
# Team1_distance_shooter_speciality                  0
# Team2_distance_shooter_speciality                  0
# Team1_engine_speciality                    0.0333333
# Team2_engine_speciality                    0.0333333
#                                             ...
# Team1_eur_release_clause                    5.63e+06
# Team2_eur_release_clause                 1.38667e+07
# Team1_eur_wage                                 26800
# Team2_eur_wage                               47433.3
# Team1_eur_value                          3.19667e+06
# Team2_eur_value                          8.73667e+06
# Team1_weight_kg                              68.1333
# Team2_weight_kg                              79.0667
# Team1_height_cm                              174.333
# Team2_height_cm                              184.867
# Team1_age                                    27.7333
# Team2_age                                    28.8333
# Team1_special                                1746.17
# Team2_special                                 1748.3
# Team1_avg_caps_GK                                 16
# Team1_avg_caps_MF                               34.3
# Team2_avg_caps_DF                            27.5714
# Team2_avg_caps_FW                                 27
# Team2_avg_caps_GK                            39.3333
# Team2_avg_caps_MF                                 25
# rank_Team1                                        70
# rank_Team2                                        66
# rank_change_Team1                                 -1
# rank_change_Team2                                 -3
# Rounds                                             1
# Time                                           18:00
# Day                                               14
# Month                                              6
# Year                                            2018
# winning_team                                      20
# Name: 64, Length: 314, dtype: object

# %%
df.shape
# Out:
# (128, 314)

# %% [markdown]
# # train & test

# %%
X_train = df.loc[df['Rounds'] == 1]
X_test = df.loc[df['Rounds'] != 1]

# %%
y_train = X_train["winning_team"]
y_test = X_test["winning_team"]

# %%
X_train = X_train.drop(["Rounds","winning_team","Time"],axis=1)
X_test = X_test.drop(["Rounds","winning_team","Time"],axis=1)

# %% [markdown]
# # train model

# %%
model = Sequential()
model.add(Dense(12, input_dim=X_train.shape[1], activation='sigmoid'))
model.add(Dense(8, activation='sigmoid'))
#model.dropout()
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy']) #categorical crossentropy?

# %%
model.fit(X_train, y_train, validation_data=(X_test,y_test), shuffle=True, epochs=100, batch_size=64)
# Out:
# Train on 96 samples, validate on 32 samples
# Epoch 1/100
# 96/96 [==============================] - 1s 13ms/step - loss: 12.7946 - acc: 0.0208 - val_loss: 10.9305 - val_acc: 0.0000e+00
# Epoch 2/100
# 96/96 [==============================] - 0s 112us/step - loss: 12.5990 - acc: 0.0208 - val_loss: 10.7663 - val_acc: 0.0000e+00
# Epoch 3/100
# 96/96 [==============================] - 0s 103us/step - loss: 12.3918 - acc: 0.0208 - val_loss: 10.6013 - val_acc: 0.0000e+00
# Epoch 4/100
# 96/96 [==============================] - 0s 102us/step - loss: 12.2096 - acc: 0.0208 - val_loss: 10.4345 - val_acc: 0.0000e+00
# Epoch 5/100
# 96/96 [==============================] - 0s 133us/step - loss: 12.0133 - acc: 0.0208 - val_loss: 10.2676 - val_acc: 0.0000e+00
# Epoch 6/100
# 96/96 [==============================] - 0s 106us/step - loss: 11.8287 - acc: 0.0208 - val_loss: 10.1008 - val_acc: 0.0000e+00
# Epoch 7/100
# 96/96 [==============================] - 0s 107us/step - loss: 11.6282 - acc: 0.0208 - val_loss: 9.9351 - val_acc: 0.0000e+00
# Epoch 8/100
# 96/96 [==============================] - 0s 96us/step - loss: 11.4320 - acc: 0.0208 - val_loss: 9.7693 - val_acc: 0.0000e+00
# Epoch 9/100
# 96/96 [==============================] - 0s 91us/step - loss: 11.2417 - acc: 0.0208 - val_loss: 9.6028 - val_acc: 0.0000e+00
# Epoch 10/100
# 96/96 [==============================] - 0s 100us/step - loss: 11.0460 - acc: 0.0208 - val_loss: 9.4364 - val_acc: 0.0000e+00
# Epoch 11/100
# 96/96 [==============================] - 0s 101us/step - loss: 10.8560 - acc: 0.0208 - val_loss: 9.2698 - val_acc: 0.0000e+00
# Epoch 12/100
# 96/96 [==============================] - 0s 128us/step - loss: 10.6646 - acc: 0.0208 - val_loss: 9.1038 - val_acc: 0.0000e+00
# Epoch 13/100
# 96/96 [==============================] - 0s 123us/step - loss: 10.4598 - acc: 0.0208 - val_loss: 8.9386 - val_acc: 0.0000e+00
# Epoch 14/100
# 96/96 [==============================] - 0s 99us/step - loss: 10.2743 - acc: 0.0208 - val_loss: 8.7722 - val_acc: 0.0000e+00
# Epoch 15/100
# 96/96 [==============================] - 0s 107us/step - loss: 10.0709 - acc: 0.0208 - val_loss: 8.6060 - val_acc: 0.0000e+00
# Epoch 16/100
# 96/96 [==============================] - 0s 106us/step - loss: 9.8861 - acc: 0.0208 - val_loss: 8.4385 - val_acc: 0.0000e+00
# Epoch 17/100
# 96/96 [==============================] - 0s 107us/step - loss: 9.6992 - acc: 0.0208 - val_loss: 8.2717 - val_acc: 0.0000e+00
# Epoch 18/100
# 96/96 [==============================] - 0s 103us/step - loss: 9.5003 - acc: 0.0208 - val_loss: 8.1067 - val_acc: 0.0000e+00
# Epoch 19/100
# 96/96 [==============================] - 0s 159us/step - loss: 9.3085 - acc: 0.0208 - val_loss: 7.9421 - val_acc: 0.0000e+00
# Epoch 20/100
# 96/96 [==============================] - 0s 132us/step - loss: 9.1138 - acc: 0.0208 - val_loss: 7.7779 - val_acc: 0.0000e+00
# Epoch 21/100
# 96/96 [==============================] - 0s 113us/step - loss: 8.9260 - acc: 0.0208 - val_loss: 7.6136 - val_acc: 0.0000e+00
# Epoch 22/100
# 96/96 [==============================] - 0s 108us/step - loss: 8.7344 - acc: 0.0208 - val_loss: 7.4497 - val_acc: 0.0000e+00
# Epoch 23/100
# 96/96 [==============================] - 0s 101us/step - loss: 8.5516 - acc: 0.0208 - val_loss: 7.2864 - val_acc: 0.0000e+00
# Epoch 24/100
# 96/96 [==============================] - 0s 86us/step - loss: 8.3582 - acc: 0.0208 - val_loss: 7.1248 - val_acc: 0.0000e+00
# Epoch 25/100
# 96/96 [==============================] - 0s 115us/step - loss: 8.1637 - acc: 0.0208 - val_loss: 6.9639 - val_acc: 0.0000e+00
# Epoch 26/100
# 96/96 [==============================] - 0s 176us/step - loss: 7.9808 - acc: 0.0208 - val_loss: 6.8023 - val_acc: 0.0000e+00
# Epoch 27/100
# 96/96 [==============================] - 0s 107us/step - loss: 7.7899 - acc: 0.0208 - val_loss: 6.6410 - val_acc: 0.0000e+00
# Epoch 28/100
# 96/96 [==============================] - 0s 97us/step - loss: 7.6031 - acc: 0.0208 - val_loss: 6.4795 - val_acc: 0.0000e+00
# Epoch 29/100
# 96/96 [==============================] - 0s 120us/step - loss: 7.4137 - acc: 0.0208 - val_loss: 6.3179 - val_acc: 0.0000e+00
# Epoch 30/100
# 96/96 [==============================] - 0s 157us/step - loss: 7.2215 - acc: 0.0208 - val_loss: 6.1560 - val_acc: 0.0000e+00
# Epoch 31/100
# 96/96 [==============================] - 0s 102us/step - loss: 7.0443 - acc: 0.0208 - val_loss: 5.9933 - val_acc: 0.0000e+00
# Epoch 32/100
# 96/96 [==============================] - 0s 109us/step - loss: 6.8490 - acc: 0.0208 - val_loss: 5.8320 - val_acc: 0.0000e+00
# Epoch 33/100
# 96/96 [==============================] - 0s 97us/step - loss: 6.6659 - acc: 0.0208 - val_loss: 5.6709 - val_acc: 0.0000e+00
# Epoch 34/100
# 96/96 [==============================] - 0s 151us/step - loss: 6.4732 - acc: 0.0208 - val_loss: 5.5107 - val_acc: 0.0000e+00
# Epoch 35/100
# 96/96 [==============================] - 0s 100us/step - loss: 6.2882 - acc: 0.0208 - val_loss: 5.3502 - val_acc: 0.0000e+00
# Epoch 36/100
# 96/96 [==============================] - 0s 101us/step - loss: 6.0956 - acc: 0.0208 - val_loss: 5.1897 - val_acc: 0.0000e+00
# Epoch 37/100
# 96/96 [==============================] - 0s 100us/step - loss: 5.9140 - acc: 0.0208 - val_loss: 5.0282 - val_acc: 0.0000e+00
# Epoch 38/100
# 96/96 [==============================] - 0s 142us/step - loss: 5.7308 - acc: 0.0208 - val_loss: 4.8671 - val_acc: 0.0000e+00
# Epoch 39/100
# 96/96 [==============================] - 0s 120us/step - loss: 5.5394 - acc: 0.0208 - val_loss: 4.7072 - val_acc: 0.0000e+00
# Epoch 40/100
# 96/96 [==============================] - 0s 105us/step - loss: 5.3538 - acc: 0.0208 - val_loss: 4.5476 - val_acc: 0.0000e+00
# Epoch 41/100
# 96/96 [==============================] - 0s 113us/step - loss: 5.1633 - acc: 0.0208 - val_loss: 4.3881 - val_acc: 0.0000e+00
# Epoch 42/100
# 96/96 [==============================] - 0s 117us/step - loss: 4.9794 - acc: 0.0208 - val_loss: 4.2279 - val_acc: 0.0000e+00
# Epoch 43/100
# 96/96 [==============================] - 0s 87us/step - loss: 4.7955 - acc: 0.0208 - val_loss: 4.0677 - val_acc: 0.0000e+00
# Epoch 44/100
# 96/96 [==============================] - 0s 162us/step - loss: 4.6085 - acc: 0.0208 - val_loss: 3.9079 - val_acc: 0.0000e+00
# Epoch 45/100
# 96/96 [==============================] - 0s 88us/step - loss: 4.4221 - acc: 0.0208 - val_loss: 3.7485 - val_acc: 0.0000e+00
# Epoch 46/100
# 96/96 [==============================] - 0s 95us/step - loss: 4.2335 - acc: 0.0208 - val_loss: 3.5893 - val_acc: 0.0000e+00
# Epoch 47/100
# 96/96 [==============================] - 0s 94us/step - loss: 4.0489 - acc: 0.0208 - val_loss: 3.4296 - val_acc: 0.0000e+00
# Epoch 48/100
# 96/96 [==============================] - 0s 101us/step - loss: 3.8639 - acc: 0.0208 - val_loss: 3.2699 - val_acc: 0.0000e+00
# Epoch 49/100
# 96/96 [==============================] - 0s 92us/step - loss: 3.6772 - acc: 0.0208 - val_loss: 3.1103 - val_acc: 0.0000e+00
# Epoch 50/100
# 96/96 [==============================] - 0s 145us/step - loss: 3.4930 - acc: 0.0208 - val_loss: 2.9508 - val_acc: 0.0000e+00
# Epoch 51/100
# 96/96 [==============================] - 0s 108us/step - loss: 3.3062 - acc: 0.0208 - val_loss: 2.7918 - val_acc: 0.0000e+00
# Epoch 52/100
# 96/96 [==============================] - 0s 102us/step - loss: 3.1139 - acc: 0.0208 - val_loss: 2.6330 - val_acc: 0.0000e+00
# Epoch 53/100
# 96/96 [==============================] - 0s 113us/step - loss: 2.9277 - acc: 0.0208 - val_loss: 2.4728 - val_acc: 0.0000e+00
# Epoch 54/100
# 96/96 [==============================] - 0s 107us/step - loss: 2.7535 - acc: 0.0208 - val_loss: 2.3117 - val_acc: 0.0000e+00
# Epoch 55/100
# 96/96 [==============================] - 0s 116us/step - loss: 2.5590 - acc: 0.0208 - val_loss: 2.1523 - val_acc: 0.0000e+00
# Epoch 56/100
# 96/96 [==============================] - 0s 107us/step - loss: 2.3701 - acc: 0.0208 - val_loss: 1.9930 - val_acc: 0.0000e+00
# Epoch 57/100
# 96/96 [==============================] - 0s 113us/step - loss: 2.1881 - acc: 0.0208 - val_loss: 1.8332 - val_acc: 0.0000e+00
# Epoch 58/100
# 96/96 [==============================] - 0s 114us/step - loss: 1.9999 - acc: 0.0208 - val_loss: 1.6738 - val_acc: 0.0000e+00
# Epoch 59/100
# 96/96 [==============================] - 0s 137us/step - loss: 1.8112 - acc: 0.0208 - val_loss: 1.5144 - val_acc: 0.0000e+00
# Epoch 60/100
# 96/96 [==============================] - 0s 108us/step - loss: 1.6391 - acc: 0.0208 - val_loss: 1.3546 - val_acc: 0.0312
# Epoch 61/100
# 96/96 [==============================] - 0s 132us/step - loss: 1.4539 - acc: 0.0417 - val_loss: 1.1977 - val_acc: 0.0312
# Epoch 62/100
# 96/96 [==============================] - 0s 123us/step - loss: 1.2630 - acc: 0.0417 - val_loss: 1.0432 - val_acc: 0.0312
# Epoch 63/100
# 96/96 [==============================] - 0s 111us/step - loss: 1.0835 - acc: 0.0417 - val_loss: 0.8888 - val_acc: 0.0312
# Epoch 64/100
# 96/96 [==============================] - 0s 106us/step - loss: 0.9011 - acc: 0.0417 - val_loss: 0.7346 - val_acc: 0.0312
# Epoch 65/100
# 96/96 [==============================] - 0s 123us/step - loss: 0.7241 - acc: 0.0312 - val_loss: 0.5803 - val_acc: 0.1562
# Epoch 66/100
# 96/96 [==============================] - 0s 128us/step - loss: 0.5286 - acc: 0.0417 - val_loss: 0.4265 - val_acc: 0.1562
# Epoch 67/100
# 96/96 [==============================] - 0s 113us/step - loss: 0.3578 - acc: 0.0417 - val_loss: 0.2698 - val_acc: 0.1562
# Epoch 68/100
# 96/96 [==============================] - 0s 124us/step - loss: 0.1824 - acc: 0.0417 - val_loss: 0.1131 - val_acc: 0.1562
# Epoch 69/100
# 96/96 [==============================] - 0s 97us/step - loss: -0.0049 - acc: 0.0417 - val_loss: -0.0420 - val_acc: 0.1562
# Epoch 70/100
# 96/96 [==============================] - 0s 115us/step - loss: -0.1900 - acc: 0.0417 - val_loss: -0.1967 - val_acc: 0.1875
# Epoch 71/100
# 96/96 [==============================] - 0s 103us/step - loss: -0.3686 - acc: 0.0625 - val_loss: -0.3519 - val_acc: 0.1875
# Epoch 72/100
# 96/96 [==============================] - 0s 100us/step - loss: -0.5514 - acc: 0.0625 - val_loss: -0.5069 - val_acc: 0.1875
# Epoch 73/100
# 96/96 [==============================] - 0s 119us/step - loss: -0.7282 - acc: 0.0625 - val_loss: -0.6619 - val_acc: 0.1875
# Epoch 74/100
# 96/96 [==============================] - 0s 166us/step - loss: -0.9189 - acc: 0.0625 - val_loss: -0.8160 - val_acc: 0.1875
# Epoch 75/100
# 96/96 [==============================] - 0s 108us/step - loss: -1.0904 - acc: 0.0625 - val_loss: -0.9712 - val_acc: 0.1875
# Epoch 76/100
# 96/96 [==============================] - 0s 112us/step - loss: -1.2807 - acc: 0.0625 - val_loss: -1.1255 - val_acc: 0.1875
# Epoch 77/100
# 96/96 [==============================] - 0s 95us/step - loss: -1.4562 - acc: 0.0625 - val_loss: -1.2807 - val_acc: 0.1875
# Epoch 78/100
# 96/96 [==============================] - 0s 141us/step - loss: -1.6377 - acc: 0.0625 - val_loss: -1.4355 - val_acc: 0.1875
# Epoch 79/100
# 96/96 [==============================] - 0s 113us/step - loss: -1.8210 - acc: 0.0625 - val_loss: -1.5898 - val_acc: 0.1875
# Epoch 80/100
# 96/96 [==============================] - 0s 120us/step - loss: -2.0020 - acc: 0.0625 - val_loss: -1.7441 - val_acc: 0.1875
# Epoch 81/100
# 96/96 [==============================] - 0s 98us/step - loss: -2.1816 - acc: 0.0625 - val_loss: -1.8984 - val_acc: 0.1875
# Epoch 82/100
# 96/96 [==============================] - 0s 110us/step - loss: -2.3676 - acc: 0.0625 - val_loss: -2.0524 - val_acc: 0.1875
# Epoch 83/100
# 96/96 [==============================] - 0s 102us/step - loss: -2.5381 - acc: 0.0625 - val_loss: -2.2070 - val_acc: 0.1875
# Epoch 84/100
# 96/96 [==============================] - 0s 79us/step - loss: -2.7242 - acc: 0.0625 - val_loss: -2.3598 - val_acc: 0.1875
# Epoch 85/100
# 96/96 [==============================] - 0s 106us/step - loss: -2.9072 - acc: 0.0625 - val_loss: -2.5123 - val_acc: 0.1875
# Epoch 86/100
# 96/96 [==============================] - 0s 133us/step - loss: -3.0823 - acc: 0.0625 - val_loss: -2.6653 - val_acc: 0.1875
# Epoch 87/100
# 96/96 [==============================] - 0s 137us/step - loss: -3.2636 - acc: 0.0625 - val_loss: -2.8176 - val_acc: 0.1875
# Epoch 88/100
# 96/96 [==============================] - 0s 97us/step - loss: -3.4397 - acc: 0.0625 - val_loss: -2.9697 - val_acc: 0.1875
# Epoch 89/100
# 96/96 [==============================] - 0s 96us/step - loss: -3.6247 - acc: 0.0625 - val_loss: -3.1211 - val_acc: 0.1875
# Epoch 90/100
# 96/96 [==============================] - 0s 99us/step - loss: -3.7991 - acc: 0.0625 - val_loss: -3.2731 - val_acc: 0.1875
# Epoch 91/100
# 96/96 [==============================] - 0s 101us/step - loss: -3.9826 - acc: 0.0625 - val_loss: -3.4248 - val_acc: 0.1875
# Epoch 92/100
# 96/96 [==============================] - 0s 129us/step - loss: -4.1513 - acc: 0.0625 - val_loss: -3.5770 - val_acc: 0.1875
# Epoch 93/100
# 96/96 [==============================] - 0s 138us/step - loss: -4.3364 - acc: 0.0625 - val_loss: -3.7276 - val_acc: 0.1875
# Epoch 94/100
# 96/96 [==============================] - 0s 188us/step - loss: -4.5125 - acc: 0.0625 - val_loss: -3.8781 - val_acc: 0.1875
# Epoch 95/100
# 96/96 [==============================] - 0s 125us/step - loss: -4.6893 - acc: 0.0625 - val_loss: -4.0283 - val_acc: 0.1875
# Epoch 96/100
# 96/96 [==============================] - 0s 130us/step - loss: -4.8658 - acc: 0.0625 - val_loss: -4.1780 - val_acc: 0.1875
# Epoch 97/100
# 96/96 [==============================] - 0s 115us/step - loss: -5.0388 - acc: 0.0625 - val_loss: -4.3271 - val_acc: 0.1875
# Epoch 98/100
# 96/96 [==============================] - 0s 97us/step - loss: -5.2147 - acc: 0.0625 - val_loss: -4.4749 - val_acc: 0.1875
# Epoch 99/100
# 96/96 [==============================] - 0s 130us/step - loss: -5.3957 - acc: 0.0625 - val_loss: -4.6217 - val_acc: 0.1875
# Epoch 100/100
# 96/96 [==============================] - 0s 104us/step - loss: -5.5674 - acc: 0.0625 - val_loss: -4.7693 - val_acc: 0.1875

# %%
scores = model.evaluate(X_test, y_test)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 32/32 [==============================] - 0s 73us/step
#
# acc: 18.75%

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

model= DecisionTreeClassifier()
model.fit(X_train,y_train)

y_pred = model.predict(X_test)

accuracy_score(y_test, y_pred)
# Out:
# 0.28125

# %%
from sklearn import svm
model_svm = svm.SVC()
model_svm.fit(X_train,y_train)

y_pred_svm = model.predict(X_test)

accuracy_score(y_test, y_pred_svm)
# Out:
# 0.21875

# %%
for c in df.keys():
    print(c)
# Out:
# Team1
# Team2
# Team1_avg_age_DF
# Team1_avg_age_FW
# Team1_avg_age_GK
# Team1_avg_age_MF
# Team2_avg_age_DF
# Team2_avg_age_FW
# Team2_avg_age_GK
# Team2_avg_age_MF
# Team1_avg_caps_DF
# Team1_avg_caps_FW
# Team1_clinical_finisher_speciality
# Team2_clinical_finisher_speciality
# Team1_strength_speciality
# Team2_strength_speciality
# Team1_acrobat_speciality
# Team2_acrobat_speciality
# Team1_tactician_speciality
# Team2_tactician_speciality
# Team1_tackling_speciality
# Team2_tackling_speciality
# Team1_free_kick_specialist_speciality
# Team2_free_kick_specialist_speciality
# Team1_crosser_speciality
# Team2_crosser_speciality
# Team1_distance_shooter_speciality
# Team2_distance_shooter_speciality
# Team1_engine_speciality
# Team2_engine_speciality
# Team1_playmaker_speciality
# Team2_playmaker_speciality
# Team1_dribbler_speciality
# Team2_dribbler_speciality
# Team1_aerial_threat_speciality
# Team2_aerial_threat_speciality
# Team1_speedster_speciality
# Team2_speedster_speciality
# Team1_poacher_speciality
# Team2_poacher_speciality
# Team1_tries_to_beat_defensive_line_trait
# Team2_tries_to_beat_defensive_line_trait
# Team1_technical_dribbler_trait
# Team2_technical_dribbler_trait
# Team1_team_player_trait
# Team2_team_player_trait
# Team1_target_forward_trait
# Team2_target_forward_trait
# Team1_takes_finesse_free_kicks_trait
# Team2_takes_finesse_free_kicks_trait
# Team1_swerve_pass_trait
# Team2_swerve_pass_trait
# Team1_stutter_penalty_trait
# Team2_stutter_penalty_trait
# Team1_skilled_dribbling_trait
# Team2_skilled_dribbling_trait
# Team1_selfish_trait
# Team2_selfish_trait
# Team1_second_wind_trait
# Team2_second_wind_trait
# Team1_saves_with_feet_trait
# Team2_saves_with_feet_trait
# Team1_rushes_out_of_goal_trait
# Team2_rushes_out_of_goal_trait
# Team1_puncher_trait
# Team2_puncher_trait
# Team1_power_header_trait
# Team2_power_header_trait
# Team1_power_free_kick_trait
# Team2_power_free_kick_trait
# Team1_playmaker_trait
# Team2_playmaker_trait
# Team1_outside_foot_shot_trait
# Team2_outside_foot_shot_trait
# Team1_one_club_player_trait
# Team2_one_club_player_trait
# Team1_long_throw_in_trait
# Team2_long_throw_in_trait
# Team1_long_shot_taker_trait
# Team2_long_shot_taker_trait
# Team1_long_passer_trait
# Team2_long_passer_trait
# Team1_leadership_trait
# Team2_leadership_trait
# Team1_injury_prone_trait
# Team2_injury_prone_trait
# Team1_injury_free_trait
# Team2_injury_free_trait
# Team1_inflexible_trait
# Team2_inflexible_trait
# Team1_giant_throw_in_trait
# Team2_giant_throw_in_trait
# Team1_gk_up_for_corners_trait
# Team2_gk_up_for_corners_trait
# Team1_gk_long_throw_trait
# Team2_gk_long_throw_trait
# Team1_gk_flat_kick_trait
# Team2_gk_flat_kick_trait
# Team1_flair_passes_trait
# Team2_flair_passes_trait
# Team1_flair_trait
# Team2_flair_trait
# Team1_finesse_shot_trait
# Team2_finesse_shot_trait
# Team1_fancy_flicks_trait
# Team2_fancy_flicks_trait
# Team1_fan's_favourite_trait
# Team2_fan's_favourite_trait
# Team1_early_crosser_trait
# Team2_early_crosser_trait
# Team1_driven_pass_trait
# Team2_driven_pass_trait
# Team1_diving_header_trait
# Team2_diving_header_trait
# Team1_dives_into_tackles_trait
# Team2_dives_into_tackles_trait
# Team1_diver_trait
# Team2_diver_trait
# Team1_corner_specialist_trait
# Team2_corner_specialist_trait
# Team1_comes_for_crosses_trait
# Team2_comes_for_crosses_trait
# Team1_chipped_penalty_trait
# Team2_chipped_penalty_trait
# Team1_chip_shot_trait
# Team2_chip_shot_trait
# Team1_cautious_with_crosses_trait
# Team2_cautious_with_crosses_trait
# Team1_bicycle_kicks_trait
# Team2_bicycle_kicks_trait
# Team1_backs_into_player_trait
# Team2_backs_into_player_trait
# Team1_avoids_using_weaker_foot_trait
# Team2_avoids_using_weaker_foot_trait
# Team1_argues_with_officials_trait
# Team2_argues_with_officials_trait
# Team1_acrobatic_clearance_trait
# Team2_acrobatic_clearance_trait
# Team1_1_on_1_rush_trait
# Team2_1_on_1_rush_trait
# Team1_gk
# Team2_gk
# Team1_lcb
# Team2_lcb
# Team1_ldm
# Team2_ldm
# Team1_lcm
# Team2_lcm
# Team1_lam
# Team2_lam
# Team1_lf
# Team2_lf
# Team1_ls
# Team2_ls
# Team1_lwb
# Team2_lwb
# Team1_lb
# Team2_lb
# Team1_cb
# Team2_cb
# Team1_cdm
# Team2_cdm
# Team1_lm
# Team2_lm
# Team1_cm
# Team2_cm
# Team1_cam
# Team2_cam
# Team1_cf
# Team2_cf
# Team1_lw
# Team2_lw
# Team1_st
# Team2_st
# Team1_rwb
# Team2_rwb
# Team1_rb
# Team2_rb
# Team1_rcb
# Team2_rcb
# Team1_rdm
# Team2_rdm
# Team1_rm
# Team2_rm
# Team1_rcm
# Team2_rcm
# Team1_ram
# Team2_ram
# Team1_rf
# Team2_rf
# Team1_rw
# Team2_rw
# Team1_rs
# Team2_rs
# Team1_gk_reflexes
# Team2_gk_reflexes
# Team1_gk_positioning
# Team2_gk_positioning
# Team1_gk_kicking
# Team2_gk_kicking
# Team1_gk_handling
# Team2_gk_handling
# Team1_gk_diving
# Team2_gk_diving
# Team1_sliding_tackle
# Team2_sliding_tackle
# Team1_standing_tackle
# Team2_standing_tackle
# Team1_marking
# Team2_marking
# Team1_composure
# Team2_composure
# Team1_penalties
# Team2_penalties
# Team1_vision
# Team2_vision
# Team1_positioning
# Team2_positioning
# Team1_interceptions
# Team2_interceptions
# Team1_aggression
# Team2_aggression
# Team1_long_shots
# Team2_long_shots
# Team1_strength
# Team2_strength
# Team1_stamina
# Team2_stamina
# Team1_jumping
# Team2_jumping
# Team1_shot_power
# Team2_shot_power
# Team1_balance
# Team2_balance
# Team1_reactions
# Team2_reactions
# Team1_agility
# Team2_agility
# Team1_sprint_speed
# Team2_sprint_speed
# Team1_acceleration
# Team2_acceleration
# Team1_ball_control
# Team2_ball_control
# Team1_long_passing
# Team2_long_passing
# Team1_free_kick_accuracy
# Team2_free_kick_accuracy
# Team1_curve
# Team2_curve
# Team1_dribbling
# Team2_dribbling
# Team1_volleys
# Team2_volleys
# Team1_short_passing
# Team2_short_passing
# Team1_heading_accuracy
# Team2_heading_accuracy
# Team1_finishing
# Team2_finishing
# Team1_crossing
# Team2_crossing
# Team1_weak_foot
# Team2_weak_foot
# Team1_skill_moves
# Team2_skill_moves
# Team1_international_reputation
# Team2_international_reputation
# Team1_phy
# Team2_phy
# Team1_def
# Team2_def
# Team1_dri
# Team2_dri
# Team1_pas
# Team2_pas
# Team1_sho
# Team2_sho
# Team1_pac
# Team2_pac
# Team1_potential
# Team2_potential
# Team1_overall
# Team2_overall
# Team1_eur_release_clause
# Team2_eur_release_clause
# Team1_eur_wage
# Team2_eur_wage
# Team1_eur_value
# Team2_eur_value
# Team1_weight_kg
# Team2_weight_kg
# Team1_height_cm
# Team2_height_cm
# Team1_age
# Team2_age
# Team1_special
# Team2_special
# Team1_avg_caps_GK
# Team1_avg_caps_MF
# Team2_avg_caps_DF
# Team2_avg_caps_FW
# Team2_avg_caps_GK
# Team2_avg_caps_MF
# rank_Team1
# rank_Team2
# rank_change_Team1
# rank_change_Team2
# Rounds
# Time
# Day
# Month
# Year
# winning_team
