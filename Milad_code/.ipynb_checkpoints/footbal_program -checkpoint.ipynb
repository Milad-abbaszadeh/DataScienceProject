# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv("../datasets/final_data/FIFA 1990-2018 - Cleaned.csv")
df_teams = pd.read_csv("../datasets/final_data/world_cup_comparisons.csv")
fifa_ranking = pd.read_csv("../datasets/final_data/fifa_ranking.csv")

# %%
df[((df.Team1 == 'IR Iran') | (df.Team2 =='IR Iran')) & (df.Year == 2018)]

# %%
df=df.replace({"South Korea":"Korea Republic"})
df = df.replace({"Iran":"IR Iran"})
df = df.replace({"Soviet Union":"Russia"})
df = df.replace({"Czechoslovakia":"Czech Republic"})


df_teams=df_teams.replace({"South Korea":"Korea Republic"})
df_teams = df_teams.replace({"Iran":"IR Iran"})

fifa_ranking=fifa_ranking.replace({"South Korea":"Korea Republic"})
fifa_ranking = fifa_ranking.replace({"Iran":"IR Iran"})

# %%
df = df[df.Year ==2018]
df
# Out:
#              Team1           Team2                    Rounds  \
# 0           Russia    Saudi Arabia               Group Phase
# 1            Egypt         Uruguay               Group Phase
# 2          Morocco         IR Iran               Group Phase
# 3         Portugal           Spain               Group Phase
# 4           France       Australia               Group Phase
# 5        Argentina         Iceland               Group Phase
# 6             Peru         Denmark               Group Phase
# 7          Croatia         Nigeria               Group Phase
# 8       Costa Rica          Serbia               Group Phase
# 9          Germany          Mexico               Group Phase
# 10          Brazil     Switzerland               Group Phase
# 11          Sweden  Korea Republic               Group Phase
# 12         Belgium          Panama               Group Phase
# 13         Tunisia         England               Group Phase
# 14        Colombia           Japan               Group Phase
# 15          Poland         Senegal               Group Phase
# 16          Russia           Egypt               Group Phase
# 17        Portugal         Morocco               Group Phase
# 18         Uruguay    Saudi Arabia               Group Phase
# 19         IR Iran           Spain               Group Phase
# 20         Denmark       Australia               Group Phase
# 21          France            Peru               Group Phase
# 22       Argentina         Croatia               Group Phase
# 23          Brazil      Costa Rica               Group Phase
# 24         Nigeria         Iceland               Group Phase
# 25          Serbia     Switzerland               Group Phase
# 26         Belgium         Tunisia               Group Phase
# 27  Korea Republic          Mexico               Group Phase
# 28         Germany          Sweden               Group Phase
# 29         England          Panama               Group Phase
# ..             ...             ...                       ...
# 34           Spain         Morocco               Group Phase
# 35         IR Iran        Portugal               Group Phase
# 36       Australia            Peru               Group Phase
# 37         Denmark          France               Group Phase
# 38         Nigeria       Argentina               Group Phase
# 39         Iceland         Croatia               Group Phase
# 40  Korea Republic         Germany               Group Phase
# 41          Mexico          Sweden               Group Phase
# 42          Serbia          Brazil               Group Phase
# 43     Switzerland      Costa Rica               Group Phase
# 44           Japan          Poland               Group Phase
# 45         Senegal        Colombia               Group Phase
# 46          Panama         Tunisia               Group Phase
# 47         England         Belgium               Group Phase
# 48          France       Argentina               Round of 16
# 49         Uruguay        Portugal               Round of 16
# 50           Spain          Russia               Round of 16
# 51         Croatia         Denmark               Round of 16
# 52          Brazil          Mexico               Round of 16
# 53         Belgium           Japan               Round of 16
# 54          Sweden     Switzerland               Round of 16
# 55        Colombia         England               Round of 16
# 56         Uruguay          France            Quarter Finals
# 57          Brazil         Belgium            Quarter Finals
# 58          Sweden         England            Quarter Finals
# 59          Russia         Croatia            Quarter Finals
# 60          France         Belgium               Semi Finals
# 61         Croatia         England               Semi Finals
# 62         Belgium         England  Play-off for third place
# 63          France         Croatia                    Finals
#
#                      Stadium             City   Time  Day  Month  Year  \
# 0           Luzhniki Stadium           Moscow  18:00   14      6  2018
# 1         Ekaterinburg Arena     Ekaterinburg  17:00   15      6  2018
# 2   Saint Petersburg Stadium   St. Petersburg  18:00   15      6  2018
# 3              Fisht Stadium            Sochi  21:00   15      6  2018
# 4                Kazan Arena            Kazan  13:00   16      6  2018
# 5            Spartak Stadium           Moscow  16:00   16      6  2018
# 6             Mordovia Arena          Saransk  19:00   16      6  2018
# 7        Kaliningrad Stadium      Kaliningrad  21:00   16      6  2018
# 8               Samara Arena           Samara  16:00   17      6  2018
# 9           Luzhniki Stadium           Moscow  18:00   17      6  2018
# 10              Rostov Arena    Rostov-On-Don  21:00   17      6  2018
# 11   Nizhny Novgorod Stadium  Nizhny Novgorod  15:00   18      6  2018
# 12             Fisht Stadium            Sochi  18:00   18      6  2018
# 13           Volgograd Arena        Volgograd  21:00   18      6  2018
# 14            Mordovia Arena          Saransk  15:00   19      6  2018
# 15           Spartak Stadium           Moscow  18:00   19      6  2018
# 16  Saint Petersburg Stadium   St. Petersburg  21:00   19      6  2018
# 17          Luzhniki Stadium           Moscow  15:00   20      6  2018
# 18              Rostov Arena    Rostov-On-Don  18:00   20      6  2018
# 19               Kazan Arena            Kazan  21:00   20      6  2018
# 20              Samara Arena           Samara  16:00   21      6  2018
# 21        Ekaterinburg Arena     Ekaterinburg  20:00   21      6  2018
# 22   Nizhny Novgorod Stadium  Nizhny Novgorod  21:00   21      6  2018
# 23  Saint Petersburg Stadium   St. Petersburg  15:00   22      6  2018
# 24           Volgograd Arena        Volgograd  18:00   22      6  2018
# 25       Kaliningrad Stadium      Kaliningrad  20:00   22      6  2018
# 26           Spartak Stadium           Moscow  15:00   23      6  2018
# 27              Rostov Arena    Rostov-On-Don  18:00   23      6  2018
# 28             Fisht Stadium            Sochi  21:00   23      6  2018
# 29   Nizhny Novgorod Stadium  Nizhny Novgorod  15:00   24      6  2018
# ..                       ...              ...    ...  ...    ...   ...
# 34       Kaliningrad Stadium      Kaliningrad  20:00   25      6  2018
# 35            Mordovia Arena          Saransk  21:00   25      6  2018
# 36             Fisht Stadium            Sochi  17:00   26      6  2018
# 37          Luzhniki Stadium           Moscow  17:00   26      6  2018
# 38  Saint Petersburg Stadium   St. Petersburg  21:00   26      6  2018
# 39              Rostov Arena    Rostov-On-Don  21:00   26      6  2018
# 40               Kazan Arena            Kazan  17:00   27      6  2018
# 41        Ekaterinburg Arena     Ekaterinburg  19:00   27      6  2018
# 42           Spartak Stadium           Moscow  21:00   27      6  2018
# 43   Nizhny Novgorod Stadium  Nizhny Novgorod  21:00   27      6  2018
# 44           Volgograd Arena        Volgograd  17:00   28      6  2018
# 45              Samara Arena           Samara  18:00   28      6  2018
# 46            Mordovia Arena          Saransk  21:00   28      6  2018
# 47       Kaliningrad Stadium      Kaliningrad  20:00   28      6  2018
# 48               Kazan Arena            Kazan  17:00   30      6  2018
# 49             Fisht Stadium            Sochi  21:00   30      6  2018
# 50          Luzhniki Stadium           Moscow  17:00    1      7  2018
# 51   Nizhny Novgorod Stadium  Nizhny Novgorod  21:00    1      7  2018
# 52              Samara Arena           Samara  18:00    2      7  2018
# 53              Rostov Arena    Rostov-On-Don  21:00    2      7  2018
# 54  Saint Petersburg Stadium   St. Petersburg  17:00    3      7  2018
# 55           Spartak Stadium           Moscow  21:00    3      7  2018
# 56   Nizhny Novgorod Stadium  Nizhny Novgorod  17:00    6      7  2018
# 57               Kazan Arena            Kazan  21:00    6      7  2018
# 58              Samara Arena           Samara  18:00    7      7  2018
# 59             Fisht Stadium            Sochi  21:00    7      7  2018
# 60  Saint Petersburg Stadium   St. Petersburg  21:00   10      7  2018
# 61          Luzhniki Stadium           Moscow  21:00   11      7  2018
# 62  Saint Petersburg Stadium   St. Petersburg  17:00   14      7  2018
# 63          Luzhniki Stadium           Moscow  18:00   15      7  2018
#
#     Score1  Score2                                            Remarks
# 0        5       0                                                NaN
# 1        0       1                                                NaN
# 2        0       1                                                NaN
# 3        3       3  {WinTeamName} win on aggregate after regular t...
# 4        2       1                                                NaN
# 5        1       1  {WinTeamName} win on aggregate after regular t...
# 6        0       1                                                NaN
# 7        2       0                                                NaN
# 8        0       1                                                NaN
# 9        0       1                                                NaN
# 10       1       1  {WinTeamName} win on aggregate after regular t...
# 11       1       0                                                NaN
# 12       3       0                                                NaN
# 13       1       2                                                NaN
# 14       1       2                                                NaN
# 15       1       2                                                NaN
# 16       3       1                                                NaN
# 17       1       0                                                NaN
# 18       1       0                                                NaN
# 19       0       1                                                NaN
# 20       1       1  {WinTeamName} win on aggregate after regular t...
# 21       1       0                                                NaN
# 22       0       3                                                NaN
# 23       2       0                                                NaN
# 24       2       0                                                NaN
# 25       1       2                                                NaN
# 26       5       2                                                NaN
# 27       1       2                                                NaN
# 28       2       1                                                NaN
# 29       6       1                                                NaN
# ..     ...     ...                                                ...
# 34       2       2  {WinTeamName} win on aggregate after regular t...
# 35       1       1  {WinTeamName} win on aggregate after regular t...
# 36       0       2                                                NaN
# 37       0       0  {WinTeamName} win on aggregate after regular t...
# 38       1       2                                                NaN
# 39       1       2                                                NaN
# 40       2       0                                                NaN
# 41       0       3                                                NaN
# 42       0       2                                                NaN
# 43       2       2  {WinTeamName} win on aggregate after regular t...
# 44       0       1                                                NaN
# 45       0       1                                                NaN
# 46       1       2                                                NaN
# 47       0       1                                                NaN
# 48       4       3                                                NaN
# 49       2       1                                                NaN
# 50       1       1  Russia win on penalties (3 - 4) RUS win after PSO
# 51       1       1  Croatia win on penalties (3 - 2) CRO win after...
# 52       2       0                                                NaN
# 53       3       2                                                NaN
# 54       1       0                                                NaN
# 55       1       1  England win on penalties (3 - 4) ENG win after...
# 56       0       2                                                NaN
# 57       1       2                                                NaN
# 58       0       2                                                NaN
# 59       2       2  Croatia win on penalties (3 - 4) CRO win after...
# 60       1       0                                                NaN
# 61       2       1           Croatia win after extra time CRO win AET
# 62       2       0                                                NaN
# 63       4       2                                                NaN
#
# [64 rows x 12 columns]

# %%
#Asia=0 Europe=2 Africa =3 america =4

continent={'Russia':'Europe', 'Germany':'Europe','Brazil':'South America','Portugal':'Europe','Argentina':'South America','Belgium':'Europe','Poland':'Europe','France':'Europe',
            'Spain':'Europe','Peru':'South America','Switzerland':'Europe','England':'Europe','Colombia':'South America','Mexico':'North America','Uruguay':'South America','Croatia':'Europe',
            'Denmark':'Europe','Iceland':'Europe','Costa Rica':'North America','Sweden':'Europe','Tunisia':'Africa','Egypt':'Asia','Senegal':'Africa','IR Iran':'Asia',
            'Serbia':'Europe','Nigeria':'Africa','Australia':'Australia','Japan':'Asia','Morocco':'Africa','Panama':'North America','Korea Republic':'Asia','Saudi Arabia':'Asia'}

# %%
ranking_2018 = fifa_ranking[(fifa_ranking['rank_date']>"2018-04-01") & (fifa_ranking['rank_date']<"2018-05-01")]
ranking_2014 = fifa_ranking[(fifa_ranking['rank_date']>"2014-04-01") & (fifa_ranking['rank_date']<"2014-05-01")]
ranking_2010 = fifa_ranking[(fifa_ranking['rank_date']>"2010-04-01") & (fifa_ranking['rank_date']<"2010-05-01")]
ranking_2006 = fifa_ranking[(fifa_ranking['rank_date']>"2006-04-01") & (fifa_ranking['rank_date']<"2006-05-01")]
ranking_2002 = fifa_ranking[(fifa_ranking['rank_date']>"2002-03-01") & (fifa_ranking['rank_date']<"2002-04-01")]
ranking_1998 = fifa_ranking[(fifa_ranking['rank_date']>"1998-04-01") & (fifa_ranking['rank_date']<"1998-05-01")]
ranking_1994 = fifa_ranking[(fifa_ranking['rank_date']>"1994-04-01") & (fifa_ranking['rank_date']<"1994-05-01")]

ranking_2018.drop_duplicates(keep='last',inplace=True)
ranking_2014.drop_duplicates(keep='last',inplace=True) 
ranking_2010.drop_duplicates(keep='last',inplace=True) 
ranking_2006.drop_duplicates(keep='last',inplace=True) 
ranking_2002.drop_duplicates(keep='last',inplace=True) 
ranking_1998.drop_duplicates(keep='last',inplace=True) 
ranking_1994.drop_duplicates(keep='last',inplace=True)
# Out:
# /home/milad/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /home/milad/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/milad/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /home/milad/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /home/milad/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /home/milad/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/milad/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
df.loc[df.Year == 2018,'rank_Team1'] = df['Team1'].map(ranking_2018.set_index('country_full')['rank'])
df.loc[df.Year == 2018,'rank_Team2'] = df['Team2'].map(ranking_2018.set_index('country_full')['rank'])

df.loc[df.Year == 2014,'rank_Team1'] = df['Team1'].map(ranking_2014.set_index('country_full')['rank'])
df.loc[df.Year == 2014,'rank_Team2'] = df['Team2'].map(ranking_2014.set_index('country_full')['rank'])

df.loc[df.Year == 2010,'rank_Team1'] = df['Team1'].map(ranking_2010.set_index('country_full')['rank'])
df.loc[df.Year == 2010,'rank_Team2'] = df['Team2'].map(ranking_2010.set_index('country_full')['rank'])

df.loc[df.Year == 2006,'rank_Team1'] = df['Team1'].map(ranking_2006.set_index('country_full')['rank'])
df.loc[df.Year == 2006,'rank_Team2'] = df['Team2'].map(ranking_2006.set_index('country_full')['rank'])

df.loc[df.Year == 2002,'rank_Team1'] = df['Team1'].map(ranking_2002.set_index('country_full')['rank'])
df.loc[df.Year == 2002,'rank_Team2'] = df['Team2'].map(ranking_2002.set_index('country_full')['rank'])

df.loc[df.Year == 1998,'rank_Team1'] = df['Team1'].map(ranking_1998.set_index('country_full')['rank'])
df.loc[df.Year == 1998,'rank_Team2'] = df['Team2'].map(ranking_1998.set_index('country_full')['rank'])

df.loc[df.Year == 1994,'rank_Team1'] = df['Team1'].map(ranking_1994.set_index('country_full')['rank'])
df.loc[df.Year == 1994,'rank_Team2'] = df['Team2'].map(ranking_1994.set_index('country_full')['rank'])

df.loc[df.Year == 1990,'rank_Team1'] = df['Team1'].map(ranking_1994.set_index('country_full')['rank'])
df.loc[df.Year == 1990,'rank_Team2'] = df['Team2'].map(ranking_1994.set_index('country_full')['rank'])

# %%
df.head()
# Out:
#       Team1         Team2       Rounds                   Stadium  \
# 0    Russia  Saudi Arabia  Group Phase          Luzhniki Stadium
# 1     Egypt       Uruguay  Group Phase        Ekaterinburg Arena
# 2   Morocco       IR Iran  Group Phase  Saint Petersburg Stadium
# 3  Portugal         Spain  Group Phase             Fisht Stadium
# 4    France     Australia  Group Phase               Kazan Arena
#
#              City   Time  Day  Month  Year  Score1  Score2  \
# 0          Moscow  18:00   14      6  2018       5       0
# 1    Ekaterinburg  17:00   15      6  2018       0       1
# 2  St. Petersburg  18:00   15      6  2018       0       1
# 3           Sochi  21:00   15      6  2018       3       3
# 4           Kazan  13:00   16      6  2018       2       1
#
#                                              Remarks  rank_Team1  rank_Team2
# 0                                                NaN        66.0        70.0
# 1                                                NaN        46.0        17.0
# 2                                                NaN        42.0        36.0
# 3  {WinTeamName} win on aggregate after regular t...         4.0         8.0
# 4                                                NaN         7.0        40.0

# %%
df= df.drop(['Stadium','City','Time','Day','Month','Year'], axis=1)

# %%
df.head()
df.shape
# Out:
# (64, 8)

# %%
df.head()
# Out:
#       Team1         Team2       Rounds  Score1  Score2  \
# 0    Russia  Saudi Arabia  Group Phase       5       0
# 1     Egypt       Uruguay  Group Phase       0       1
# 2   Morocco       IR Iran  Group Phase       0       1
# 3  Portugal         Spain  Group Phase       3       3
# 4    France     Australia  Group Phase       2       1
#
#                                              Remarks  rank_Team1  rank_Team2
# 0                                                NaN        66.0        70.0
# 1                                                NaN        46.0        17.0
# 2                                                NaN        42.0        36.0
# 3  {WinTeamName} win on aggregate after regular t...         4.0         8.0
# 4                                                NaN         7.0        40.0

# %%
#Adding Continent 
continent_list1 = []
continent_list2 = []

for i in range (len(df['Team1'])):
    if df['Team1'][i] in continent:
        continent_list1.append(continent[df['Team1'][i]])
    else:
        print(df['Team1'][i])
        
for j in range (len(df['Team2'])):   
    if df['Team2'][j] in continent:
        continent_list2.append(continent[df['Team2'][j]])

df['continent_team1'] = continent_list1
df['continent_team2'] = continent_list2
df.head()
# Out:
#       Team1         Team2       Rounds  Score1  Score2  \
# 0    Russia  Saudi Arabia  Group Phase       5       0
# 1     Egypt       Uruguay  Group Phase       0       1
# 2   Morocco       IR Iran  Group Phase       0       1
# 3  Portugal         Spain  Group Phase       3       3
# 4    France     Australia  Group Phase       2       1
#
#                                              Remarks  rank_Team1  rank_Team2  \
# 0                                                NaN        66.0        70.0
# 1                                                NaN        46.0        17.0
# 2                                                NaN        42.0        36.0
# 3  {WinTeamName} win on aggregate after regular t...         4.0         8.0
# 4                                                NaN         7.0        40.0
#
#   continent_team1 continent_team2
# 0          Europe            Asia
# 1            Asia   South America
# 2          Africa            Asia
# 3          Europe          Europe
# 4          Europe       Australia

# %%
df
# Out:
#              Team1           Team2                    Rounds  Score1  Score2  \
# 0           Russia    Saudi Arabia               Group Phase       5       0
# 1            Egypt         Uruguay               Group Phase       0       1
# 2          Morocco         IR Iran               Group Phase       0       1
# 3         Portugal           Spain               Group Phase       3       3
# 4           France       Australia               Group Phase       2       1
# 5        Argentina         Iceland               Group Phase       1       1
# 6             Peru         Denmark               Group Phase       0       1
# 7          Croatia         Nigeria               Group Phase       2       0
# 8       Costa Rica          Serbia               Group Phase       0       1
# 9          Germany          Mexico               Group Phase       0       1
# 10          Brazil     Switzerland               Group Phase       1       1
# 11          Sweden  Korea Republic               Group Phase       1       0
# 12         Belgium          Panama               Group Phase       3       0
# 13         Tunisia         England               Group Phase       1       2
# 14        Colombia           Japan               Group Phase       1       2
# 15          Poland         Senegal               Group Phase       1       2
# 16          Russia           Egypt               Group Phase       3       1
# 17        Portugal         Morocco               Group Phase       1       0
# 18         Uruguay    Saudi Arabia               Group Phase       1       0
# 19         IR Iran           Spain               Group Phase       0       1
# 20         Denmark       Australia               Group Phase       1       1
# 21          France            Peru               Group Phase       1       0
# 22       Argentina         Croatia               Group Phase       0       3
# 23          Brazil      Costa Rica               Group Phase       2       0
# 24         Nigeria         Iceland               Group Phase       2       0
# 25          Serbia     Switzerland               Group Phase       1       2
# 26         Belgium         Tunisia               Group Phase       5       2
# 27  Korea Republic          Mexico               Group Phase       1       2
# 28         Germany          Sweden               Group Phase       2       1
# 29         England          Panama               Group Phase       6       1
# ..             ...             ...                       ...     ...     ...
# 34           Spain         Morocco               Group Phase       2       2
# 35         IR Iran        Portugal               Group Phase       1       1
# 36       Australia            Peru               Group Phase       0       2
# 37         Denmark          France               Group Phase       0       0
# 38         Nigeria       Argentina               Group Phase       1       2
# 39         Iceland         Croatia               Group Phase       1       2
# 40  Korea Republic         Germany               Group Phase       2       0
# 41          Mexico          Sweden               Group Phase       0       3
# 42          Serbia          Brazil               Group Phase       0       2
# 43     Switzerland      Costa Rica               Group Phase       2       2
# 44           Japan          Poland               Group Phase       0       1
# 45         Senegal        Colombia               Group Phase       0       1
# 46          Panama         Tunisia               Group Phase       1       2
# 47         England         Belgium               Group Phase       0       1
# 48          France       Argentina               Round of 16       4       3
# 49         Uruguay        Portugal               Round of 16       2       1
# 50           Spain          Russia               Round of 16       1       1
# 51         Croatia         Denmark               Round of 16       1       1
# 52          Brazil          Mexico               Round of 16       2       0
# 53         Belgium           Japan               Round of 16       3       2
# 54          Sweden     Switzerland               Round of 16       1       0
# 55        Colombia         England               Round of 16       1       1
# 56         Uruguay          France            Quarter Finals       0       2
# 57          Brazil         Belgium            Quarter Finals       1       2
# 58          Sweden         England            Quarter Finals       0       2
# 59          Russia         Croatia            Quarter Finals       2       2
# 60          France         Belgium               Semi Finals       1       0
# 61         Croatia         England               Semi Finals       2       1
# 62         Belgium         England  Play-off for third place       2       0
# 63          France         Croatia                    Finals       4       2
#
#                                               Remarks  rank_Team1  rank_Team2  \
# 0                                                 NaN        66.0        70.0
# 1                                                 NaN        46.0        17.0
# 2                                                 NaN        42.0        36.0
# 3   {WinTeamName} win on aggregate after regular t...         4.0         8.0
# 4                                                 NaN         7.0        40.0
# 5   {WinTeamName} win on aggregate after regular t...         5.0        22.0
# 6                                                 NaN        11.0        12.0
# 7                                                 NaN        18.0        47.0
# 8                                                 NaN        25.0        35.0
# 9                                                 NaN         1.0        15.0
# 10  {WinTeamName} win on aggregate after regular t...         2.0         6.0
# 11                                                NaN        23.0        61.0
# 12                                                NaN         3.0        55.0
# 13                                                NaN        14.0        13.0
# 14                                                NaN        16.0        60.0
# 15                                                NaN        10.0        28.0
# 16                                                NaN        66.0        46.0
# 17                                                NaN         4.0        42.0
# 18                                                NaN        17.0        70.0
# 19                                                NaN        36.0         8.0
# 20  {WinTeamName} win on aggregate after regular t...        12.0        40.0
# 21                                                NaN         7.0        11.0
# 22                                                NaN         5.0        18.0
# 23                                                NaN         2.0        25.0
# 24                                                NaN        47.0        22.0
# 25                                                NaN        35.0         6.0
# 26                                                NaN         3.0        14.0
# 27                                                NaN        61.0        15.0
# 28                                                NaN         1.0        23.0
# 29                                                NaN        13.0        55.0
# ..                                                ...         ...         ...
# 34  {WinTeamName} win on aggregate after regular t...         8.0        42.0
# 35  {WinTeamName} win on aggregate after regular t...        36.0         4.0
# 36                                                NaN        40.0        11.0
# 37  {WinTeamName} win on aggregate after regular t...        12.0         7.0
# 38                                                NaN        47.0         5.0
# 39                                                NaN        22.0        18.0
# 40                                                NaN        61.0         1.0
# 41                                                NaN        15.0        23.0
# 42                                                NaN        35.0         2.0
# 43  {WinTeamName} win on aggregate after regular t...         6.0        25.0
# 44                                                NaN        60.0        10.0
# 45                                                NaN        28.0        16.0
# 46                                                NaN        55.0        14.0
# 47                                                NaN        13.0         3.0
# 48                                                NaN         7.0         5.0
# 49                                                NaN        17.0         4.0
# 50  Russia win on penalties (3 - 4) RUS win after PSO         8.0        66.0
# 51  Croatia win on penalties (3 - 2) CRO win after...        18.0        12.0
# 52                                                NaN         2.0        15.0
# 53                                                NaN         3.0        60.0
# 54                                                NaN        23.0         6.0
# 55  England win on penalties (3 - 4) ENG win after...        16.0        13.0
# 56                                                NaN        17.0         7.0
# 57                                                NaN         2.0         3.0
# 58                                                NaN        23.0        13.0
# 59  Croatia win on penalties (3 - 4) CRO win after...        66.0        18.0
# 60                                                NaN         7.0         3.0
# 61           Croatia win after extra time CRO win AET        18.0        13.0
# 62                                                NaN         3.0        13.0
# 63                                                NaN         7.0        18.0
#
#    continent_team1 continent_team2
# 0           Europe            Asia
# 1             Asia   South America
# 2           Africa            Asia
# 3           Europe          Europe
# 4           Europe       Australia
# 5    South America          Europe
# 6    South America          Europe
# 7           Europe          Africa
# 8    North America          Europe
# 9           Europe   North America
# 10   South America          Europe
# 11          Europe            Asia
# 12          Europe   North America
# 13          Africa          Europe
# 14   South America            Asia
# 15          Europe          Africa
# 16          Europe            Asia
# 17          Europe          Africa
# 18   South America            Asia
# 19            Asia          Europe
# 20          Europe       Australia
# 21          Europe   South America
# 22   South America          Europe
# 23   South America   North America
# 24          Africa          Europe
# 25          Europe          Europe
# 26          Europe          Africa
# 27            Asia   North America
# 28          Europe          Europe
# 29          Europe   North America
# ..             ...             ...
# 34          Europe          Africa
# 35            Asia          Europe
# 36       Australia   South America
# 37          Europe          Europe
# 38          Africa   South America
# 39          Europe          Europe
# 40            Asia          Europe
# 41   North America          Europe
# 42          Europe   South America
# 43          Europe   North America
# 44            Asia          Europe
# 45          Africa   South America
# 46   North America          Africa
# 47          Europe          Europe
# 48          Europe   South America
# 49   South America          Europe
# 50          Europe          Europe
# 51          Europe          Europe
# 52   South America   North America
# 53          Europe            Asia
# 54          Europe          Europe
# 55   South America          Europe
# 56   South America          Europe
# 57   South America          Europe
# 58          Europe          Europe
# 59          Europe          Europe
# 60          Europe          Europe
# 61          Europe          Europe
# 62          Europe          Europe
# 63          Europe          Europe
#
# [64 rows x 10 columns]

# %%
df[((df.continent_team1 == 'Europe') & (df.continent_team2 =='Asia')) |((df.continent_team2 == 'Asia') & (df.continent_team1 =='Europe'))]
# Out:
#       Team1           Team2       Rounds  Score1  Score2 Remarks  rank_Team1  \
# 0    Russia    Saudi Arabia  Group Phase       5       0     NaN        66.0
# 11   Sweden  Korea Republic  Group Phase       1       0     NaN        23.0
# 16   Russia           Egypt  Group Phase       3       1     NaN        66.0
# 53  Belgium           Japan  Round of 16       3       2     NaN         3.0
#
#     rank_Team2 continent_team1 continent_team2
# 0         70.0          Europe            Asia
# 11        61.0          Europe            Asia
# 16        46.0          Europe            Asia
# 53        60.0          Europe            Asia

# %%
continent_dict = {"Australia":1, "Asia":2, "Europe":3, "Africa":4, "North America":5, "South America":6}
continent_encoded_team1 = []
continent_encoded_team2 = []


for i in range(len(df.continent_team1)):
    continent_encoded_team1.append(continent_dict[list(df.continent_team1)[i]])
    continent_encoded_team2.append(continent_dict[list(df.continent_team2)[i]])
    
df["continent_encoded_team1"] = continent_encoded_team1
df["continent_encoded_team2"] = continent_encoded_team2

# %%
df.head()
# Out:
#       Team1         Team2       Rounds  Score1  Score2  \
# 0    Russia  Saudi Arabia  Group Phase       5       0
# 1     Egypt       Uruguay  Group Phase       0       1
# 2   Morocco       IR Iran  Group Phase       0       1
# 3  Portugal         Spain  Group Phase       3       3
# 4    France     Australia  Group Phase       2       1
#
#                                              Remarks  rank_Team1  rank_Team2  \
# 0                                                NaN        66.0        70.0
# 1                                                NaN        46.0        17.0
# 2                                                NaN        42.0        36.0
# 3  {WinTeamName} win on aggregate after regular t...         4.0         8.0
# 4                                                NaN         7.0        40.0
#
#   continent_team1 continent_team2  continent_encoded_team1  \
# 0          Europe            Asia                        3
# 1            Asia   South America                        2
# 2          Africa            Asia                        4
# 3          Europe          Europe                        3
# 4          Europe       Australia                        3
#
#    continent_encoded_team2
# 0                        2
# 1                        6
# 2                        2
# 3                        3
# 4                        1

# %%
#Adding who is the continent winner 
continent_winner = []
for i in range (len(df['Team1'])):
    if df['continent_encoded_team1'][i] > df['continent_encoded_team2'][i]:
        continent_winner.append(df['Team1'][i])
    elif df['continent_encoded_team1'][i] < df['continent_encoded_team2'][i]:
        continent_winner.append(df['Team2'][i])
        
    elif df['rank_Team1'][i] > df['rank_Team2'][i]:
        continent_winner.append(df['Team2'][i])
    else:
        continent_winner.append(df['Team1'][i])

df['continent_winner'] = continent_winner
df.head()
# Out:
#       Team1         Team2       Rounds  Score1  Score2  \
# 0    Russia  Saudi Arabia  Group Phase       5       0
# 1     Egypt       Uruguay  Group Phase       0       1
# 2   Morocco       IR Iran  Group Phase       0       1
# 3  Portugal         Spain  Group Phase       3       3
# 4    France     Australia  Group Phase       2       1
#
#                                              Remarks  rank_Team1  rank_Team2  \
# 0                                                NaN        66.0        70.0
# 1                                                NaN        46.0        17.0
# 2                                                NaN        42.0        36.0
# 3  {WinTeamName} win on aggregate after regular t...         4.0         8.0
# 4                                                NaN         7.0        40.0
#
#   continent_team1 continent_team2  continent_encoded_team1  \
# 0          Europe            Asia                        3
# 1            Asia   South America                        2
# 2          Africa            Asia                        4
# 3          Europe          Europe                        3
# 4          Europe       Australia                        3
#
#    continent_encoded_team2 continent_winner
# 0                        2           Russia
# 1                        6          Uruguay
# 2                        2          Morocco
# 3                        3         Portugal
# 4                        1           France

# %%
countries = list(set(df["Team1"]).union(set(df["Team2"])))
countries_dict = {}
for i in range(len(countries)):
    countries_dict[countries[i]] = i
    
Team1_encoded = []
Team2_encoded = []

for i in range(len(df)):
    Team1_encoded.append(countries_dict[list(df.Team1)[i]])
    Team2_encoded.append(countries_dict[list(df.Team2)[i]])
    
df["Team1"] = Team1_encoded
df["Team2"] = Team2_encoded

# %%
#Adding who is the winner 
winner = []
for i in range (len(df['Team1'])):
    if df['Score1'][i] > df['Score2'][i]:
        winner.append(df['Team1'][i])
    elif df['Score1'][i] < df['Score2'][i]:
        winner.append(df['Team2'][i])
    else:
        winner.append('Draw')

df['winner'] = winner
df.head()
# Out:
#       Team1         Team2       Rounds  Score1  Score2  \
# 0    Russia  Saudi Arabia  Group Phase       5       0
# 1     Egypt       Uruguay  Group Phase       0       1
# 2   Morocco       IR Iran  Group Phase       0       1
# 3  Portugal         Spain  Group Phase       3       3
# 4    France     Australia  Group Phase       2       1
#
#                                              Remarks  rank_Team1  rank_Team2  \
# 0                                                NaN        66.0        70.0
# 1                                                NaN        46.0        17.0
# 2                                                NaN        42.0        36.0
# 3  {WinTeamName} win on aggregate after regular t...         4.0         8.0
# 4                                                NaN         7.0        40.0
#
#   continent_team1 continent_team2  continent_encoded_team1  \
# 0          Europe            Asia                        3
# 1            Asia   South America                        2
# 2          Africa            Asia                        4
# 3          Europe          Europe                        3
# 4          Europe       Australia                        3
#
#    continent_encoded_team2 continent_winner   winner
# 0                        2           Russia   Russia
# 1                        6          Uruguay  Uruguay
# 2                        2          Morocco  IR Iran
# 3                        3         Portugal     Draw
# 4                        1           France   France

# %%
df.isnull().sum()
# Out:
# Team1                       0
# Team2                       0
# Rounds                      0
# Score1                      0
# Score2                      0
# Remarks                    50
# rank_Team1                  0
# rank_Team2                  0
# continent_team1             0
# continent_team2             0
# continent_encoded_team1     0
# continent_encoded_team2     0
# continent_winner            0
# winner                      0
# dtype: int64

# %%
df= df.drop(['Rounds'], axis=1)

# %%
df.head()
# Out:
#       Team1         Team2       Rounds  Score1  Score2  \
# 0    Russia  Saudi Arabia  Group Phase       5       0
# 1     Egypt       Uruguay  Group Phase       0       1
# 2   Morocco       IR Iran  Group Phase       0       1
# 3  Portugal         Spain  Group Phase       3       3
# 4    France     Australia  Group Phase       2       1
#
#                                              Remarks  rank_Team1  rank_Team2  \
# 0                                                NaN        66.0        70.0
# 1                                                NaN        46.0        17.0
# 2                                                NaN        42.0        36.0
# 3  {WinTeamName} win on aggregate after regular t...         4.0         8.0
# 4                                                NaN         7.0        40.0
#
#   continent_team1 continent_team2  continent_encoded_team1  \
# 0          Europe            Asia                        3
# 1            Asia   South America                        2
# 2          Africa            Asia                        4
# 3          Europe          Europe                        3
# 4          Europe       Australia                        3
#
#    continent_encoded_team2 continent_winner   winner
# 0                        2           Russia   Russia
# 1                        6          Uruguay  Uruguay
# 2                        2          Morocco  IR Iran
# 3                        3         Portugal     Draw
# 4                        1           France   France

# %%
df4 = df[df.continent_winner==df.winner]

# %%
df4.shape
# Out:
# (29, 14)

# %%
23/64
# Out:
# 0.359375

# %%
df3= df[(df.Rounds !='Group Phase') & (df.winner == 'Draw')]

# %%
df3

# %%
pred_winner = []
for j in range (len(df['Team1'])):
    if df['rank_Team1'][j] >= df['rank_Team2'][j]:
        pred_winner.append(df['Team2'][j])
    else:
        pred_winner.append(df['Team1'][j])
df['pred_win'] = pred_winner

# %%
df.head()
# Out:
#       Team1         Team2       Rounds  Score1  Score2  \
# 0    Russia  Saudi Arabia  Group Phase       5       0
# 1     Egypt       Uruguay  Group Phase       0       1
# 2   Morocco       IR Iran  Group Phase       0       1
# 3  Portugal         Spain  Group Phase       3       3
# 4    France     Australia  Group Phase       2       1
#
#                                              Remarks  rank_Team1  rank_Team2  \
# 0                                                NaN        66.0        70.0
# 1                                                NaN        46.0        17.0
# 2                                                NaN        42.0        36.0
# 3  {WinTeamName} win on aggregate after regular t...         4.0         8.0
# 4                                                NaN         7.0        40.0
#
#   continent_team1 continent_team2  continent_encoded_team1  \
# 0          Europe            Asia                        3
# 1            Asia   South America                        2
# 2          Africa            Asia                        4
# 3          Europe          Europe                        3
# 4          Europe       Australia                        3
#
#    continent_encoded_team2 continent_winner   winner  pred_win
# 0                        2           Russia   Russia    Russia
# 1                        6          Uruguay  Uruguay   Uruguay
# 2                        2          Morocco  IR Iran   IR Iran
# 3                        3         Portugal     Draw  Portugal
# 4                        1           France   France    France

# %%
df[(df.continent_winner == df.winner) & (df.winner==df.pred_win)].shape
# Out:
# (23, 15)

# %%
df= df.drop(['Score1','Score2'], axis=1)
X=df 
y = df.winner

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

model_tree= DecisionTreeClassifier()
model_tree.fit(X_train,y_train)

y_pred_tree = model_tree.predict(X_test)

accuracy_score(y_test, y_pred_tree)

# %%
df2 = df[df.winner == df.pred_win]

# %%
df2.shape

# %%
35/64

# %%
df.iloc[10:64]
