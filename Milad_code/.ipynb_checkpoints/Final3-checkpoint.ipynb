# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.models import Sequential
from keras.layers import Dense
import category_encoders as ce
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv("../datasets/final_data/FIFA Data 1990-2018.csv")
df_teams = pd.read_csv("../datasets/final_data/world_cup_comparisons.csv")
fifa_ranking = pd.read_csv("../datasets/final_data/fifa_ranking.csv")
continent = pd.read_csv("../datasets/final_data/countries and continents1.csv",encoding ='utf-8',na_filter = False)
big_df = pd.read_csv("../datasets/results.csv")

big_df=big_df.replace({"South Korea":"Korea Republic"})
big_df = big_df.replace({"Iran":"IR Iran"})
big_df = big_df.replace({"Soviet Union":"Russia"})
big_df = big_df.replace({"Czechoslovakia":"Czech Republic"})




df=df.replace({"South Korea":"Korea Republic"})
df = df.replace({"Iran":"IR Iran"})
df = df.replace({"Soviet Union":"Russia"})
df = df.replace({"Czechoslovakia":"Czech Republic"})


df_teams=df_teams.replace({"South Korea":"Korea Republic"})
df_teams = df_teams.replace({"Iran":"IR Iran"})

fifa_ranking=fifa_ranking.replace({"South Korea":"Korea Republic"})
fifa_ranking = fifa_ranking.replace({"Iran":"IR Iran"})

# %%
df =df.drop(['Winner'],axis=1)
df.head()
# Out:
#       Team1         Team2       Rounds   Year_com  Day  Month  Year  Score1  \
# 0    Russia  Saudi Arabia  Group Phase  2018-6-14   14      6  2018       5
# 1     Egypt       Uruguay  Group Phase  2018-6-15   15      6  2018       0
# 2   Morocco       IR Iran  Group Phase  2018-6-15   15      6  2018       0
# 3  Portugal         Spain  Group Phase  2018-6-15   15      6  2018       3
# 4    France     Australia  Group Phase  2018-6-16   16      6  2018       2
#
#    Score2  Ranking T1  Score T1  Ranking T2  Score T2
# 0       0        70.0     457.0        67.0     465.0
# 1       1        45.0     649.0        14.0    1018.0
# 2       1        41.0     686.0        37.0     708.0
# 3       3         4.0    1274.0        10.0    1126.0
# 4       1         7.0    1198.0        36.0     718.0

# %%
big_df.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country
# 0  Scotland
# 1   England
# 2  Scotland
# 3   England
# 4  Scotland

# %%
#Adding who is the winner 
winner_big = []
for i in range (len(big_df['home_team'])):
    if big_df['home_score'][i] > big_df['away_score'][i]:
        winner_big.append(big_df['home_team'][i])
        
    elif big_df['home_score'][i] < big_df['away_score'][i]:
        winner_big.append(big_df['away_team'][i])
        
    else:
        winner_big.append('Draw')


big_df['winner'] = winner_big
big_df.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country    winner
# 0  Scotland      Draw
# 1   England   England
# 2  Scotland  Scotland
# 3   England      Draw
# 4  Scotland  Scotland

# %%
df.head()
# Out:
#       Team1         Team2       Rounds   Year_com  Day  Month  Year  Score1  \
# 0    Russia  Saudi Arabia  Group Phase  2018-6-14   14      6  2018       5
# 1     Egypt       Uruguay  Group Phase  2018-6-15   15      6  2018       0
# 2   Morocco       IR Iran  Group Phase  2018-6-15   15      6  2018       0
# 3  Portugal         Spain  Group Phase  2018-6-15   15      6  2018       3
# 4    France     Australia  Group Phase  2018-6-16   16      6  2018       2
#
#    Score2  Ranking T1  Score T1  Ranking T2  Score T2
# 0       0        70.0     457.0        67.0     465.0
# 1       1        45.0     649.0        14.0    1018.0
# 2       1        41.0     686.0        37.0     708.0
# 3       3         4.0    1274.0        10.0    1126.0
# 4       1         7.0    1198.0        36.0     718.0

# %% [markdown]
# # Duplicate

# %%
# we should change all respective column for duplicate
for index,row in df.iterrows():
    df.set_value(index+488,["Team1","Team2","Rounds","Year_com",'Day','Month','Year',"Score1","Score2",'Ranking T1','Score T1','Ranking T2','Score T2'],[row["Team2"],row["Team1"],row["Rounds"],row['Year_com'],row['Day'],row['Month'],row["Year"],row["Score2"],row["Score1"],row['Ranking T2'],row['Score T2'],row['Ranking T1'],row['Score T1']])
df.shape
# Out:
# /home/milad/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.
# (976, 13)

# %%
df.iloc[0]
# Out:
# Team1               Russia
# Team2         Saudi Arabia
# Rounds         Group Phase
# Year_com         2018-6-14
# Day                     14
# Month                    6
# Year                  2018
# Score1                   5
# Score2                   0
# Ranking T1              70
# Score T1               457
# Ranking T2              67
# Score T2               465
# Name: 0, dtype: object

# %%
df.iloc[488]
# Out:
# Team1         Saudi Arabia
# Team2               Russia
# Rounds         Group Phase
# Year_com         2018-6-14
# Day                     14
# Month                    6
# Year                  2018
# Score1                   0
# Score2                   5
# Ranking T1              67
# Score T1               465
# Ranking T2              70
# Score T2               457
# Name: 488, dtype: object

# %%
def data_collection(n,Team,Year_complete,big_df):
    temp = big_df[((big_df['home_team'] == Team)|(big_df['away_team'] == Team))&(big_df['date']< Year_complete)&(big_df['tournament'] !='FIFA World Cup')].tail(n)
    number_of_winning = temp[temp['winner'] == Team].count()[0]
    number_of_failure = temp[((temp['winner'] != Team) & (temp['winner'] != 'Draw'))].count()[0]
    number_of_draw =    temp[temp['winner'] == 'Draw'].count()[0]
    print(Team," ",number_of_winning," ",number_of_failure," ",number_of_draw)
    return number_of_winning,number_of_failure,number_of_draw

# %%
NW1_1 =[]
NF1_1= []
ND1_1= []

NW1_2 =[]
NF1_2= []
ND1_2= []

for i in range (len(df['Team1'])):
    NW1,NF1,ND1 = data_collection(100,df['Team1'][i],df['Year_com'][i],big_df)
    NW2,NF2,ND2 = data_collection(100,df['Team2'][i],df['Year_com'][i],big_df)
    
    NW1_1.append(NW1)
    NF1_1.append(NF1)
    ND1_1.append(ND1)
    
    NW1_2.append(NW2)
    NF1_2.append(NF2)
    ND1_2.append(ND2)
    
df['NW1'] = NW1_1 
df['NF1'] = NF1_1  
df['ND1'] = ND1_1

df['NW2'] = NW1_2 
df['NF2'] = NF1_2  
df['ND2'] = ND1_2
# Out:
# Russia   48   25   27
# Saudi Arabia   41   36   23
# Egypt   62   24   14
# Uruguay   46   26   28
# Morocco   43   26   31
# IR Iran   63   14   23
# Portugal   62   18   20
# Spain   72   13   15
# France   59   20   21
# Australia   50   26   24
# Argentina   60   16   24
# Iceland   40   41   19
# Peru   39   36   25
# Denmark   42   31   27
# Croatia   58   18   24
# Nigeria   48   20   32
# Costa Rica   40   32   28
# Serbia   47   34   19
# Germany   64   15   21
# Mexico   55   22   23
# Brazil   71   11   18
# Switzerland   54   24   22
# Sweden   53   28   19
# Korea Republic   53   27   20
# Belgium   56   22   22
# Panama   40   30   30
# Tunisia   42   25   33
# England   62   13   25
# Colombia   48   26   26
# Japan   57   21   22
# Poland   46   24   30
# Senegal   47   22   31
# Russia   48   25   27
# Egypt   62   24   14
# Portugal   62   18   20
# Morocco   43   26   31
# Uruguay   46   26   28
# Saudi Arabia   41   36   23
# IR Iran   63   14   23
# Spain   72   13   15
# Denmark   42   31   27
# Australia   50   26   24
# France   59   20   21
# Peru   39   36   25
# Argentina   60   16   24
# Croatia   58   18   24
# Brazil   71   11   18
# Costa Rica   40   32   28
# Nigeria   48   20   32
# Iceland   40   41   19
# Serbia   47   34   19
# Switzerland   54   24   22
# Belgium   56   22   22
# Tunisia   42   25   33
# Korea Republic   53   27   20
# Mexico   55   22   23
# Germany   64   15   21
# Sweden   53   28   19
# England   62   13   25
# Panama   40   30   30
# Japan   57   21   22
# Senegal   47   22   31
# Poland   46   24   30
# Colombia   48   26   26
# Uruguay   46   26   28
# Russia   48   25   27
# Saudi Arabia   41   36   23
# Egypt   62   24   14
# Spain   72   13   15
# Morocco   43   26   31
# IR Iran   63   14   23
# Portugal   62   18   20
# Australia   50   26   24
# Peru   39   36   25
# Denmark   42   31   27
# France   59   20   21
# Nigeria   48   20   32
# Argentina   60   16   24
# Iceland   40   41   19
# Croatia   58   18   24
# Korea Republic   53   27   20
# Germany   64   15   21
# Mexico   55   22   23
# Sweden   53   28   19
# Serbia   47   34   19
# Brazil   71   11   18
# Switzerland   54   24   22
# Costa Rica   40   32   28
# Japan   57   21   22
# Poland   46   24   30
# Senegal   47   22   31
# Colombia   48   26   26
# Panama   40   30   30
# Tunisia   42   25   33
# England   62   13   25
# Belgium   56   22   22
# France   59   20   21
# Argentina   60   16   24
# Uruguay   46   26   28
# Portugal   62   18   20
# Spain   72   13   15
# Russia   48   25   27
# Croatia   58   18   24
# Denmark   42   31   27
# Brazil   71   11   18
# Mexico   55   22   23
# Belgium   56   22   22
# Japan   57   21   22
# Sweden   53   28   19
# Switzerland   54   24   22
# Colombia   48   26   26
# England   62   13   25
# Uruguay   46   26   28
# France   59   20   21
# Brazil   71   11   18
# Belgium   56   22   22
# Sweden   53   28   19
# England   62   13   25
# Russia   48   25   27
# Croatia   58   18   24
# France   59   20   21
# Belgium   56   22   22
# Croatia   58   18   24
# England   62   13   25
# Belgium   56   22   22
# England   62   13   25
# France   59   20   21
# Croatia   58   18   24
# Brazil   71   11   18
# Croatia   60   18   22
# Mexico   56   23   21
# Cameroon   50   22   28
# Spain   80   10   10
# Netherlands   62   17   21
# Chile   50   30   20
# Australia   49   27   24
# Colombia   49   26   25
# Greece   50   24   26
# Uruguay   48   22   30
# Costa Rica   40   32   28
# England   64   16   20
# Italy   49   18   33
# Côte dIvoire   0   0   0
# Japan   56   23   21
# Switzerland   48   25   27
# Ecuador   32   41   27
# France   54   21   25
# Honduras   41   35   24
# Argentina   60   18   22
# Bosnia and Herzegovina   0   0   0
# Germany   65   15   20
# Portugal   56   18   26
# IR Iran   56   16   28
# Nigeria   49   19   32
# Ghana   50   28   22
# USA   55   30   15
# Belgium   42   32   26
# Algeria   45   33   22
# Brazil   71   11   18
# Mexico   56   23   21
# Russia   53   18   29
# Korea Republic   49   25   26
# Australia   49   27   24
# Netherlands   62   17   21
# Spain   80   10   10
# Chile   50   30   20
# Cameroon   50   22   28
# Croatia   60   18   22
# Colombia   49   26   25
# Côte dIvoire   0   0   0
# Uruguay   48   22   30
# England   64   16   20
# Japan   56   23   21
# Greece   50   24   26
# Italy   49   18   33
# Costa Rica   40   32   28
# Switzerland   48   25   27
# France   54   21   25
# Honduras   41   35   24
# Ecuador   32   41   27
# Argentina   60   18   22
# IR Iran   56   16   28
# Germany   65   15   20
# Ghana   50   28   22
# Nigeria   49   19   32
# Bosnia and Herzegovina   0   0   0
# Belgium   42   32   26
# Russia   53   18   29
# Korea Republic   49   25   26
# Algeria   45   33   22
# USA   55   30   15
# Portugal   56   18   26
# Australia   49   27   24
# Spain   80   10   10
# Netherlands   62   17   21
# Chile   50   30   20
# Cameroon   50   22   28
# Brazil   71   11   18
# Croatia   60   18   22
# Mexico   56   23   21
# Italy   49   18   33
# Uruguay   48   22   30
# Costa Rica   40   32   28
# England   64   16   20
# Japan   56   23   21
# Colombia   49   26   25
# Greece   50   24   26
# Côte dIvoire   0   0   0
# Nigeria   49   19   32
# Argentina   60   18   22
# Bosnia and Herzegovina   0   0   0
# IR Iran   56   16   28
# Honduras   41   35   24
# Switzerland   48   25   27
# Ecuador   32   41   27
# France   54   21   25
# USA   55   30   15
# Germany   65   15   20
# Portugal   56   18   26
# Ghana   50   28   22
# Korea Republic   49   25   26
# Belgium   42   32   26
# Algeria   45   33   22
# Russia   53   18   29
# Brazil   71   11   18
# Chile   50   30   20
# Colombia   49   26   25
# Uruguay   48   22   30
# France   54   21   25
# Nigeria   49   19   32
# Germany   65   15   20
# Algeria   45   33   22
# Brazil   71   11   18
# Colombia   49   26   25
# France   54   21   25
# Germany   65   15   20
# Brazil   71   11   18
# Germany   65   15   20
# Brazil   71   11   18
# Netherlands   62   17   21
# Germany   65   15   20
# Argentina   60   18   22
# Netherlands   62   17   21
# Argentina   60   18   22
# Netherlands   62   17   21
# Costa Rica   40   32   28
# Argentina   60   18   22
# Belgium   42   32   26
# Netherlands   62   17   21
# Mexico   56   23   21
# Costa Rica   40   32   28
# Greece   50   24   26
# Argentina   60   18   22
# Switzerland   48   25   27
# Belgium   42   32   26
# USA   55   30   15
# South Africa   40   34   26
# Mexico   57   29   14
# Uruguay   43   28   29
# France   61   16   23
# Korea Republic   48   21   31
# Greece   52   26   22
# Argentina   62   20   18
# Nigeria   55   19   26
# England   61   19   20
# USA   59   25   16
# Algeria   35   36   29
# Slovenia   37   37   26
# Serbia   43   31   26
# Ghana   41   32   27
# Germany   62   17   21
# Australia   57   24   19
# Netherlands   65   12   23
# Denmark   51   22   27
# Japan   54   22   24
# Cameroon   52   23   25
# Italy   52   16   32
# Paraguay   38   32   30
# New Zealand   37   48   15
# Slovakia   37   38   25
# Côte dIvoire   0   0   0
# Portugal   58   15   27
# Brazil   65   11   24
# Korea Republic   48   21   31
# Honduras   50   28   22
# Chile   46   30   24
# Spain   75   8   17
# Switzerland   42   32   26
# South Africa   40   34   26
# Uruguay   43   28   29
# Argentina   62   20   18
# Korea Republic   48   21   31
# Greece   52   26   22
# Nigeria   55   19   26
# France   61   16   23
# Mexico   57   29   14
# Germany   62   17   21
# Serbia   43   31   26
# Slovenia   37   37   26
# USA   59   25   16
# England   61   19   20
# Algeria   35   36   29
# Netherlands   65   12   23
# Japan   54   22   24
# Ghana   41   32   27
# Australia   57   24   19
# Cameroon   52   23   25
# Denmark   51   22   27
# Slovakia   37   38   25
# Paraguay   38   32   30
# Italy   52   16   32
# New Zealand   37   48   15
# Brazil   65   11   24
# Côte dIvoire   0   0   0
# Portugal   58   15   27
# Korea Republic   48   21   31
# Chile   46   30   24
# Switzerland   42   32   26
# Spain   75   8   17
# Honduras   50   28   22
# Mexico   57   29   14
# Uruguay   43   28   29
# France   61   16   23
# South Africa   40   34   26
# Nigeria   55   19   26
# Korea Republic   48   21   31
# Greece   52   26   22
# Argentina   62   20   18
# Slovenia   37   37   26
# England   61   19   20
# USA   59   25   16
# Algeria   35   36   29
# Ghana   41   32   27
# Germany   62   17   21
# Australia   57   24   19
# Serbia   43   31   26
# Slovakia   37   38   25
# Italy   52   16   32
# Paraguay   38   32   30
# New Zealand   37   48   15
# Denmark   51   22   27
# Japan   54   22   24
# Cameroon   52   23   25
# Netherlands   65   12   23
# Portugal   58   15   27
# Brazil   65   11   24
# Korea Republic   48   21   31
# Côte dIvoire   0   0   0
# Chile   46   30   24
# Spain   75   8   17
# Switzerland   42   32   26
# Honduras   50   28   22
# Uruguay   43   28   29
# Korea Republic   48   21   31
# USA   59   25   16
# Ghana   41   32   27
# Germany   62   17   21
# England   61   19   20
# Argentina   62   20   18
# Mexico   57   29   14
# Netherlands   65   12   23
# Slovakia   37   38   25
# Brazil   65   11   24
# Chile   46   30   24
# Paraguay   38   32   30
# Japan   54   22   24
# Spain   75   8   17
# Portugal   58   15   27
# Netherlands   65   12   23
# Brazil   65   11   24
# Uruguay   43   28   29
# Ghana   41   32   27
# Argentina   62   20   18
# Germany   62   17   21
# Paraguay   38   32   30
# Spain   75   8   17
# Uruguay   43   28   29
# Netherlands   65   12   23
# Germany   62   17   21
# Spain   75   8   17
# Uruguay   43   28   29
# Germany   62   17   21
# Netherlands   65   12   23
# Spain   75   8   17
# Germany   53   24   23
# Costa Rica   45   35   20
# Poland   53   27   20
# Ecuador   36   39   25
# England   53   19   28
# Paraguay   39   30   31
# Trinidad and Tobago   42   42   16
# Sweden   44   22   34
# Argentina   60   18   22
# Côte dIvoire   0   0   0
# Serbia and Montenegro   0   0   0
# Netherlands   56   11   33
# Mexico   52   28   20
# IR Iran   62   17   21
# Angola   40   27   33
# Portugal   62   14   24
# Australia   61   23   16
# Japan   53   25   22
# USA   58   22   20
# Czech Republic   65   19   16
# Italy   51   16   33
# Ghana   40   34   26
# Korea Republic   42   28   30
# Togo   35   43   22
# France   69   10   21
# Switzerland   37   34   29
# Brazil   54   19   27
# Croatia   47   19   34
# Spain   62   14   24
# Ukraine   40   26   34
# Tunisia   49   21   30
# Saudi Arabia   55   24   21
# Germany   53   24   23
# Poland   53   27   20
# Ecuador   36   39   25
# Costa Rica   45   35   20
# England   53   19   28
# Trinidad and Tobago   42   42   16
# Sweden   44   22   34
# Paraguay   39   30   31
# Argentina   60   18   22
# Serbia and Montenegro   0   0   0
# Netherlands   56   11   33
# Côte dIvoire   0   0   0
# Mexico   52   28   20
# Angola   40   27   33
# Portugal   62   14   24
# IR Iran   62   17   21
# Czech Republic   65   19   16
# Ghana   40   34   26
# Italy   51   16   33
# USA   58   22   20
# Japan   53   25   22
# Croatia   47   19   34
# Brazil   54   19   27
# Australia   61   23   16
# France   69   10   21
# Korea Republic   42   28   30
# Togo   35   43   22
# Switzerland   37   34   29
# Saudi Arabia   55   24   21
# Ukraine   40   26   34
# Spain   62   14   24
# Tunisia   49   21   30
# Ecuador   36   39   25
# Germany   53   24   23
# Costa Rica   45   35   20
# Poland   53   27   20
# Sweden   44   22   34
# England   53   19   28
# Paraguay   39   30   31
# Trinidad and Tobago   42   42   16
# IR Iran   62   17   21
# Angola   40   27   33
# Portugal   62   14   24
# Mexico   52   28   20
# Netherlands   56   11   33
# Argentina   60   18   22
# Côte dIvoire   0   0   0
# Serbia and Montenegro   0   0   0
# Czech Republic   65   19   16
# Italy   51   16   33
# Ghana   40   34   26
# USA   58   22   20
# Japan   53   25   22
# Brazil   54   19   27
# Croatia   47   19   34
# Australia   61   23   16
# Ukraine   40   26   34
# Tunisia   49   21   30
# Saudi Arabia   55   24   21
# Spain   62   14   24
# Togo   35   43   22
# France   69   10   21
# Switzerland   37   34   29
# Korea Republic   42   28   30
# Germany   53   24   23
# Sweden   44   22   34
# Argentina   60   18   22
# Mexico   52   28   20
# England   53   19   28
# Ecuador   36   39   25
# Portugal   62   14   24
# Netherlands   56   11   33
# Italy   51   16   33
# Australia   61   23   16
# Switzerland   37   34   29
# Ukraine   40   26   34
# Brazil   54   19   27
# Ghana   40   34   26
# Spain   62   14   24
# France   69   10   21
# Germany   53   24   23
# Argentina   60   18   22
# Italy   51   16   33
# Ukraine   40   26   34
# England   53   19   28
# Portugal   62   14   24
# Brazil   54   19   27
# France   69   10   21
# Germany   53   24   23
# Italy   51   16   33
# Portugal   62   14   24
# France   69   10   21
# Germany   53   24   23
# Portugal   62   14   24
# Italy   51   16   33
# France   69   10   21
# France   63   11   26
# Senegal   40   27   33
# Uruguay   40   35   25
# Denmark   54   21   25
# Republic of Ireland   0   0   0
# Cameroon   45   24   31
# Germany   59   17   24
# Saudi Arabia   56   23   21
# Argentina   56   18   26
# Nigeria   49   21   30
# Paraguay   43   30   27
# South Africa   47   26   27
# England   46   19   35
# Sweden   47   20   33
# Spain   63   11   26
# Slovenia   32   31   27
# Brazil   66   17   17
# Turkey   44   32   24
# Italy   55   18   27
# Ecuador   41   34   25
# Croatia   48   18   34
# Mexico   49   29   22
# China   50   26   24
# Costa Rica   43   30   27
# Japan   48   25   27
# Belgium   46   28   26
# Korea Republic   46   19   35
# Poland   40   33   27
# Russia   51   21   28
# Tunisia   48   26   26
# USA   48   27   25
# Portugal   56   16   28
# Germany   59   17   24
# Republic of Ireland   0   0   0
# Denmark   54   21   25
# Senegal   40   27   33
# Cameroon   45   24   31
# Saudi Arabia   56   23   21
# France   63   11   26
# Uruguay   40   35   25
# Sweden   47   20   33
# Nigeria   49   21   30
# Argentina   56   18   26
# England   46   19   35
# Spain   63   11   26
# Paraguay   43   30   27
# South Africa   47   26   27
# Slovenia   32   31   27
# Brazil   66   17   17
# China   50   26   24
# Italy   55   18   27
# Croatia   48   18   34
# Costa Rica   43   30   27
# Turkey   44   32   24
# Japan   48   25   27
# Russia   51   21   28
# Mexico   49   29   22
# Ecuador   41   34   25
# Korea Republic   46   19   35
# USA   48   27   25
# Portugal   56   16   28
# Poland   40   33   27
# Tunisia   48   26   26
# Belgium   46   28   26
# Denmark   54   21   25
# France   63   11   26
# Senegal   40   27   33
# Uruguay   40   35   25
# Saudi Arabia   56   23   21
# Republic of Ireland   0   0   0
# Cameroon   45   24   31
# Germany   59   17   24
# Sweden   47   20   33
# Argentina   56   18   26
# Nigeria   49   21   30
# England   46   19   35
# Slovenia   32   31   27
# Paraguay   43   30   27
# South Africa   47   26   27
# Spain   63   11   26
# Costa Rica   43   30   27
# Brazil   66   17   17
# Turkey   44   32   24
# China   50   26   24
# Ecuador   41   34   25
# Croatia   48   18   34
# Mexico   49   29   22
# Italy   55   18   27
# Tunisia   48   26   26
# Japan   48   25   27
# Portugal   56   16   28
# Korea Republic   46   19   35
# Poland   40   33   27
# USA   48   27   25
# Belgium   46   28   26
# Russia   51   21   28
# Denmark   54   21   25
# England   46   19   35
# Germany   59   17   24
# Paraguay   43   30   27
# Spain   63   11   26
# Republic of Ireland   0   0   0
# Sweden   47   20   33
# Senegal   40   27   33
# Brazil   66   17   17
# Belgium   46   28   26
# Mexico   49   29   22
# USA   48   27   25
# Japan   48   25   27
# Turkey   44   32   24
# Korea Republic   46   19   35
# Italy   55   18   27
# England   46   19   35
# Brazil   66   17   17
# Germany   59   17   24
# USA   48   27   25
# Senegal   40   27   33
# Turkey   44   32   24
# Spain   63   11   26
# Korea Republic   46   19   35
# Germany   59   17   24
# Korea Republic   46   19   35
# Brazil   66   17   17
# Turkey   44   32   24
# Korea Republic   46   19   35
# Turkey   44   32   24
# Germany   59   17   24
# Brazil   66   17   17
# Brazil   69   9   22
# Scotland   44   30   26
# Morocco   51   18   31
# Norway   48   20   32
# Italy   57   15   28
# Chile   43   33   24
# Cameroon   40   27   33
# Austria   38   39   23
# Paraguay   44   32   24
# Bulgaria   41   34   25
# Saudi Arabia   52   24   24
# Denmark   50   23   27
# France   55   13   32
# South Africa   45   27   19
# Spain   56   18   26
# Nigeria   44   28   28
# Korea Republic   48   22   30
# Mexico   45   25   30
# Netherlands   57   20   23
# Belgium   45   28   27
# Argentina   49   17   34
# Japan   50   27   23
# Yugoslavia   54   28   18
# IR Iran   49   23   28
# Jamaica   48   24   28
# Croatia   39   14   17
# England   51   14   35
# Tunisia   48   23   29
# Romania   53   24   23
# Colombia   42   23   35
# Germany   64   12   24
# USA   41   32   27
# Scotland   44   30   26
# Norway   48   20   32
# Brazil   69   9   22
# Morocco   51   18   31
# Chile   43   33   24
# Austria   38   39   23
# Italy   57   15   28
# Cameroon   40   27   33
# South Africa   45   27   19
# Denmark   50   23   27
# France   55   13   32
# Saudi Arabia   52   24   24
# Nigeria   44   28   28
# Bulgaria   41   34   25
# Spain   56   18   26
# Paraguay   44   32   24
# Japan   50   27   23
# Croatia   39   14   17
# Belgium   45   28   27
# Mexico   45   25   30
# Netherlands   57   20   23
# Korea Republic   48   22   30
# Germany   64   12   24
# Yugoslavia   54   28   18
# Argentina   49   17   34
# Jamaica   48   24   28
# USA   41   32   27
# IR Iran   49   23   28
# Colombia   42   23   35
# Tunisia   48   23   29
# Romania   53   24   23
# England   51   14   35
# Italy   57   15   28
# Austria   38   39   23
# Chile   43   33   24
# Cameroon   40   27   33
# Scotland   44   30   26
# Morocco   51   18   31
# Brazil   69   9   22
# Norway   48   20   32
# France   55   13   32
# Denmark   50   23   27
# South Africa   45   27   19
# Saudi Arabia   52   24   24
# Spain   56   18   26
# Bulgaria   41   34   25
# Nigeria   44   28   28
# Paraguay   44   32   24
# Belgium   45   28   27
# Korea Republic   48   22   30
# Netherlands   57   20   23
# Mexico   45   25   30
# Germany   64   12   24
# IR Iran   49   23   28
# USA   41   32   27
# Yugoslavia   54   28   18
# Japan   50   27   23
# Jamaica   48   24   28
# Argentina   49   17   34
# Croatia   39   14   17
# Romania   53   24   23
# Tunisia   48   23   29
# Colombia   42   23   35
# England   51   14   35
# Italy   57   15   28
# Norway   48   20   32
# Brazil   69   9   22
# Chile   43   33   24
# France   55   13   32
# Paraguay   44   32   24
# Nigeria   44   28   28
# Denmark   50   23   27
# Germany   64   12   24
# Mexico   45   25   30
# Netherlands   57   20   23
# Yugoslavia   54   28   18
# Romania   53   24   23
# Croatia   39   14   17
# Argentina   49   17   34
# England   51   14   35
# Italy   57   15   28
# France   55   13   32
# Brazil   69   9   22
# Denmark   50   23   27
# Netherlands   57   20   23
# Argentina   49   17   34
# Germany   64   12   24
# Croatia   39   14   17
# Brazil   69   9   22
# Netherlands   57   20   23
# France   55   13   32
# Croatia   39   14   17
# Netherlands   57   20   23
# Croatia   39   14   17
# Brazil   69   9   22
# France   55   13   32
# Spain   54   23   23
# Korea Republic   53   16   31
# Germany   56   18   26
# Bolivia   22   50   28
# USA   32   38   30
# Switzerland   42   30   28
# Italy   56   18   26
# Republic of Ireland   0   0   0
# Colombia   47   20   33
# Romania   49   24   27
# Belgium   45   30   25
# Morocco   39   24   37
# Norway   38   31   31
# Mexico   52   20   28
# Cameroon   46   21   33
# Sweden   54   22   24
# Netherlands   55   21   24
# Saudi Arabia   46   27   27
# Brazil   57   15   28
# Russia   49   20   31
# Argentina   38   24   38
# Greece   38   34   28
# Nigeria   45   23   32
# Bulgaria   39   33   28
# Germany   56   18   26
# Spain   54   23   23
# Romania   49   24   27
# Switzerland   42   30   28
# USA   32   38   30
# Colombia   47   20   33
# Italy   56   18   26
# Norway   38   31   31
# Korea Republic   53   16   31
# Bolivia   22   50   28
# Mexico   52   20   28
# Republic of Ireland   0   0   0
# Sweden   54   22   24
# Russia   49   20   31
# Brazil   57   15   28
# Cameroon   46   21   33
# Belgium   45   30   25
# Netherlands   55   21   24
# Saudi Arabia   46   27   27
# Morocco   39   24   37
# Argentina   38   24   38
# Nigeria   45   23   32
# Bulgaria   39   33   28
# Greece   38   34   28
# USA   32   38   30
# Romania   49   24   27
# Switzerland   42   30   28
# Colombia   47   20   33
# Germany   56   18   26
# Korea Republic   53   16   31
# Bolivia   22   50   28
# Spain   54   23   23
# Republic of Ireland   0   0   0
# Norway   38   31   31
# Brazil   57   15   28
# Sweden   54   22   24
# Italy   56   18   26
# Mexico   52   20   28
# Russia   49   20   31
# Cameroon   46   21   33
# Morocco   39   24   37
# Netherlands   55   21   24
# Belgium   45   30   25
# Saudi Arabia   46   27   27
# Greece   38   34   28
# Nigeria   45   23   32
# Argentina   38   24   38
# Bulgaria   39   33   28
# Germany   56   18   26
# Belgium   45   30   25
# Spain   54   23   23
# Switzerland   42   30   28
# Saudi Arabia   46   27   27
# Sweden   54   22   24
# Romania   49   24   27
# Argentina   38   24   38
# Netherlands   55   21   24
# Republic of Ireland   0   0   0
# Brazil   57   15   28
# USA   32   38   30
# Nigeria   45   23   32
# Italy   56   18   26
# Mexico   52   20   28
# Bulgaria   39   33   28
# Italy   56   18   26
# Spain   54   23   23
# Netherlands   55   21   24
# Brazil   57   15   28
# Bulgaria   39   33   28
# Germany   56   18   26
# Romania   49   24   27
# Sweden   54   22   24
# Bulgaria   39   33   28
# Italy   56   18   26
# Sweden   54   22   24
# Brazil   57   15   28
# Sweden   54   22   24
# Bulgaria   39   33   28
# Brazil   57   15   28
# Italy   56   18   26
# Spain   50   25   25
# Korea Republic   58   20   22
# Russia   54   20   26
# Romania   42   29   29
# United Arab Emirates   42   35   23
# Colombia   39   33   28
# Italy   50   20   30
# Republic of Ireland   0   0   0
# USA   33   39   28
# Czech Republic   42   30   28
# Brazil   58   15   27
# Sweden   50   26   24
# Germany   57   19   24
# Yugoslavia   52   29   19
# Costa Rica   36   27   37
# Scotland   40   34   26
# Netherlands   52   28   20
# Saudi Arabia   41   31   28
# Belgium   44   30   26
# Korea Republic   58   20   22
# Netherlands   52   28   20
# Egypt   41   28   31
# Uruguay   51   20   29
# Spain   50   25   25
# Argentina   34   29   37
# Russia   54   20   26
# Cameroon   49   22   29
# Romania   42   29   29
# Yugoslavia   52   29   19
# Colombia   39   33   28
# Italy   50   20   30
# USA   33   39   28
# Korea Republic   58   20   22
# Bolivia   20   60   20
# Mexico   57   17   26
# Republic of Ireland   0   0   0
# Brazil   58   15   27
# Costa Rica   36   27   37
# Sweden   50   26   24
# Scotland   40   34   26
# England   51   19   30
# Netherlands   52   28   20
# Saudi Arabia   41   31   28
# Morocco   40   25   35
# Korea Republic   58   20   22
# Spain   50   25   25
# Belgium   44   30   26
# Uruguay   51   20   29
# Argentina   34   29   37
# Romania   42   29   29
# Cameroon   49   22   29
# Russia   54   20   26
# Germany   57   19   24
# Korea Republic   58   20   22
# Yugoslavia   52   29   19
# United Arab Emirates   42   35   23
# Republic of Ireland   0   0   0
# Norway   32   39   29
# Austria   41   33   26
# USA   33   39   28
# Brazil   58   15   27
# Scotland   40   34   26
# Sweden   50   26   24
# Costa Rica   36   27   37
# Korea Republic   58   20   22
# Uruguay   51   20   29
# Belgium   44   30   26
# Saudi Arabia   41   31   28
# Republic of Ireland   0   0   0
# Netherlands   52   28   20
# England   51   19   30
# Egypt   41   28   31
# Cameroon   49   22   29
# Colombia   39   33   28
# Czech Republic   42   30   28
# Costa Rica   36   27   37
# Saudi Arabia   41   31   28
# Sweden   50   26   24
# Germany   57   19   24
# Netherlands   52   28   20
# Netherlands   52   28   20
# Republic of Ireland   0   0   0
# Italy   50   20   30
# Uruguay   51   20   29
# Spain   50   25   25
# Yugoslavia   52   29   19
# England   51   19   30
# Belgium   44   30   26
# Yugoslavia   52   29   19
# Argentina   34   29   37
# Italy   50   20   30
# Republic of Ireland   0   0   0
# Germany   57   19   24
# Czech Republic   42   30   28
# England   51   19   30
# Cameroon   49   22   29
# Italy   50   20   30
# Argentina   34   29   37
# Germany   57   19   24
# Czech Republic   42   30   28
# Italy   50   20   30
# England   51   19   30
# Germany   57   19   24
# Argentina   34   29   37
# Saudi Arabia   41   36   23
# Russia   48   25   27
# Uruguay   46   26   28
# Egypt   62   24   14
# IR Iran   63   14   23
# Morocco   43   26   31
# Spain   72   13   15
# Portugal   62   18   20
# Australia   50   26   24
# France   59   20   21
# Iceland   40   41   19
# Argentina   60   16   24
# Denmark   42   31   27
# Peru   39   36   25
# Nigeria   48   20   32
# Croatia   58   18   24
# Serbia   47   34   19
# Costa Rica   40   32   28
# Mexico   55   22   23
# Germany   64   15   21
# Switzerland   54   24   22
# Brazil   71   11   18
# Korea Republic   53   27   20
# Sweden   53   28   19
# Panama   40   30   30
# Belgium   56   22   22
# England   62   13   25
# Tunisia   42   25   33
# Japan   57   21   22
# Colombia   48   26   26
# Senegal   47   22   31
# Poland   46   24   30
# Egypt   62   24   14
# Russia   48   25   27
# Morocco   43   26   31
# Portugal   62   18   20
# Saudi Arabia   41   36   23
# Uruguay   46   26   28
# Spain   72   13   15
# IR Iran   63   14   23
# Australia   50   26   24
# Denmark   42   31   27
# Peru   39   36   25
# France   59   20   21
# Croatia   58   18   24
# Argentina   60   16   24
# Costa Rica   40   32   28
# Brazil   71   11   18
# Iceland   40   41   19
# Nigeria   48   20   32
# Switzerland   54   24   22
# Serbia   47   34   19
# Tunisia   42   25   33
# Belgium   56   22   22
# Mexico   55   22   23
# Korea Republic   53   27   20
# Sweden   53   28   19
# Germany   64   15   21
# Panama   40   30   30
# England   62   13   25
# Senegal   47   22   31
# Japan   57   21   22
# Colombia   48   26   26
# Poland   46   24   30
# Russia   48   25   27
# Uruguay   46   26   28
# Egypt   62   24   14
# Saudi Arabia   41   36   23
# Morocco   43   26   31
# Spain   72   13   15
# Portugal   62   18   20
# IR Iran   63   14   23
# Peru   39   36   25
# Australia   50   26   24
# France   59   20   21
# Denmark   42   31   27
# Argentina   60   16   24
# Nigeria   48   20   32
# Croatia   58   18   24
# Iceland   40   41   19
# Germany   64   15   21
# Korea Republic   53   27   20
# Sweden   53   28   19
# Mexico   55   22   23
# Brazil   71   11   18
# Serbia   47   34   19
# Costa Rica   40   32   28
# Switzerland   54   24   22
# Poland   46   24   30
# Japan   57   21   22
# Colombia   48   26   26
# Senegal   47   22   31
# Tunisia   42   25   33
# Panama   40   30   30
# Belgium   56   22   22
# England   62   13   25
# Argentina   60   16   24
# France   59   20   21
# Portugal   62   18   20
# Uruguay   46   26   28
# Russia   48   25   27
# Spain   72   13   15
# Denmark   42   31   27
# Croatia   58   18   24
# Mexico   55   22   23
# Brazil   71   11   18
# Japan   57   21   22
# Belgium   56   22   22
# Switzerland   54   24   22
# Sweden   53   28   19
# England   62   13   25
# Colombia   48   26   26
# France   59   20   21
# Uruguay   46   26   28
# Belgium   56   22   22
# Brazil   71   11   18
# England   62   13   25
# Sweden   53   28   19
# Croatia   58   18   24
# Russia   48   25   27
# Belgium   56   22   22
# France   59   20   21
# England   62   13   25
# Croatia   58   18   24
# England   62   13   25
# Belgium   56   22   22
# Croatia   58   18   24
# France   59   20   21
# Croatia   60   18   22
# Brazil   71   11   18
# Cameroon   50   22   28
# Mexico   56   23   21
# Netherlands   62   17   21
# Spain   80   10   10
# Australia   49   27   24
# Chile   50   30   20
# Greece   50   24   26
# Colombia   49   26   25
# Costa Rica   40   32   28
# Uruguay   48   22   30
# Italy   49   18   33
# England   64   16   20
# Japan   56   23   21
# Côte dIvoire   0   0   0
# Ecuador   32   41   27
# Switzerland   48   25   27
# Honduras   41   35   24
# France   54   21   25
# Bosnia and Herzegovina   0   0   0
# Argentina   60   18   22
# Portugal   56   18   26
# Germany   65   15   20
# Nigeria   49   19   32
# IR Iran   56   16   28
# USA   55   30   15
# Ghana   50   28   22
# Algeria   45   33   22
# Belgium   42   32   26
# Mexico   56   23   21
# Brazil   71   11   18
# Korea Republic   49   25   26
# Russia   53   18   29
# Netherlands   62   17   21
# Australia   49   27   24
# Chile   50   30   20
# Spain   80   10   10
# Croatia   60   18   22
# Cameroon   50   22   28
# Côte dIvoire   0   0   0
# Colombia   49   26   25
# England   64   16   20
# Uruguay   48   22   30
# Greece   50   24   26
# Japan   56   23   21
# Costa Rica   40   32   28
# Italy   49   18   33
# France   54   21   25
# Switzerland   48   25   27
# Ecuador   32   41   27
# Honduras   41   35   24
# IR Iran   56   16   28
# Argentina   60   18   22
# Ghana   50   28   22
# Germany   65   15   20
# Bosnia and Herzegovina   0   0   0
# Nigeria   49   19   32
# Russia   53   18   29
# Belgium   42   32   26
# Algeria   45   33   22
# Korea Republic   49   25   26
# Portugal   56   18   26
# USA   55   30   15
# Spain   80   10   10
# Australia   49   27   24
# Chile   50   30   20
# Netherlands   62   17   21
# Brazil   71   11   18
# Cameroon   50   22   28
# Mexico   56   23   21
# Croatia   60   18   22
# Uruguay   48   22   30
# Italy   49   18   33
# England   64   16   20
# Costa Rica   40   32   28
# Colombia   49   26   25
# Japan   56   23   21
# Côte dIvoire   0   0   0
# Greece   50   24   26
# Argentina   60   18   22
# Nigeria   49   19   32
# IR Iran   56   16   28
# Bosnia and Herzegovina   0   0   0
# Switzerland   48   25   27
# Honduras   41   35   24
# France   54   21   25
# Ecuador   32   41   27
# Germany   65   15   20
# USA   55   30   15
# Ghana   50   28   22
# Portugal   56   18   26
# Belgium   42   32   26
# Korea Republic   49   25   26
# Russia   53   18   29
# Algeria   45   33   22
# Chile   50   30   20
# Brazil   71   11   18
# Uruguay   48   22   30
# Colombia   49   26   25
# Nigeria   49   19   32
# France   54   21   25
# Algeria   45   33   22
# Germany   65   15   20
# Colombia   49   26   25
# Brazil   71   11   18
# Germany   65   15   20
# France   54   21   25
# Germany   65   15   20
# Brazil   71   11   18
# Netherlands   62   17   21
# Brazil   71   11   18
# Argentina   60   18   22
# Germany   65   15   20
# Argentina   60   18   22
# Netherlands   62   17   21
# Costa Rica   40   32   28
# Netherlands   62   17   21
# Belgium   42   32   26
# Argentina   60   18   22
# Mexico   56   23   21
# Netherlands   62   17   21
# Greece   50   24   26
# Costa Rica   40   32   28
# Switzerland   48   25   27
# Argentina   60   18   22
# USA   55   30   15
# Belgium   42   32   26
# Mexico   57   29   14
# South Africa   40   34   26
# France   61   16   23
# Uruguay   43   28   29
# Greece   52   26   22
# Korea Republic   48   21   31
# Nigeria   55   19   26
# Argentina   62   20   18
# USA   59   25   16
# England   61   19   20
# Slovenia   37   37   26
# Algeria   35   36   29
# Ghana   41   32   27
# Serbia   43   31   26
# Australia   57   24   19
# Germany   62   17   21
# Denmark   51   22   27
# Netherlands   65   12   23
# Cameroon   52   23   25
# Japan   54   22   24
# Paraguay   38   32   30
# Italy   52   16   32
# Slovakia   37   38   25
# New Zealand   37   48   15
# Portugal   58   15   27
# Côte dIvoire   0   0   0
# Korea Republic   48   21   31
# Brazil   65   11   24
# Chile   46   30   24
# Honduras   50   28   22
# Switzerland   42   32   26
# Spain   75   8   17
# Uruguay   43   28   29
# South Africa   40   34   26
# Korea Republic   48   21   31
# Argentina   62   20   18
# Nigeria   55   19   26
# Greece   52   26   22
# Mexico   57   29   14
# France   61   16   23
# Serbia   43   31   26
# Germany   62   17   21
# USA   59   25   16
# Slovenia   37   37   26
# Algeria   35   36   29
# England   61   19   20
# Japan   54   22   24
# Netherlands   65   12   23
# Australia   57   24   19
# Ghana   41   32   27
# Denmark   51   22   27
# Cameroon   52   23   25
# Paraguay   38   32   30
# Slovakia   37   38   25
# New Zealand   37   48   15
# Italy   52   16   32
# Côte dIvoire   0   0   0
# Brazil   65   11   24
# Korea Republic   48   21   31
# Portugal   58   15   27
# Switzerland   42   32   26
# Chile   46   30   24
# Honduras   50   28   22
# Spain   75   8   17
# Uruguay   43   28   29
# Mexico   57   29   14
# South Africa   40   34   26
# France   61   16   23
# Korea Republic   48   21   31
# Nigeria   55   19   26
# Argentina   62   20   18
# Greece   52   26   22
# England   61   19   20
# Slovenia   37   37   26
# Algeria   35   36   29
# USA   59   25   16
# Germany   62   17   21
# Ghana   41   32   27
# Serbia   43   31   26
# Australia   57   24   19
# Italy   52   16   32
# Slovakia   37   38   25
# New Zealand   37   48   15
# Paraguay   38   32   30
# Japan   54   22   24
# Denmark   51   22   27
# Netherlands   65   12   23
# Cameroon   52   23   25
# Brazil   65   11   24
# Portugal   58   15   27
# Côte dIvoire   0   0   0
# Korea Republic   48   21   31
# Spain   75   8   17
# Chile   46   30   24
# Honduras   50   28   22
# Switzerland   42   32   26
# Korea Republic   48   21   31
# Uruguay   43   28   29
# Ghana   41   32   27
# USA   59   25   16
# England   61   19   20
# Germany   62   17   21
# Mexico   57   29   14
# Argentina   62   20   18
# Slovakia   37   38   25
# Netherlands   65   12   23
# Chile   46   30   24
# Brazil   65   11   24
# Japan   54   22   24
# Paraguay   38   32   30
# Portugal   58   15   27
# Spain   75   8   17
# Brazil   65   11   24
# Netherlands   65   12   23
# Ghana   41   32   27
# Uruguay   43   28   29
# Germany   62   17   21
# Argentina   62   20   18
# Spain   75   8   17
# Paraguay   38   32   30
# Netherlands   65   12   23
# Uruguay   43   28   29
# Spain   75   8   17
# Germany   62   17   21
# Germany   62   17   21
# Uruguay   43   28   29
# Spain   75   8   17
# Netherlands   65   12   23
# Costa Rica   45   35   20
# Germany   53   24   23
# Ecuador   36   39   25
# Poland   53   27   20
# Paraguay   39   30   31
# England   53   19   28
# Sweden   44   22   34
# Trinidad and Tobago   42   42   16
# Côte dIvoire   0   0   0
# Argentina   60   18   22
# Netherlands   56   11   33
# Serbia and Montenegro   0   0   0
# IR Iran   62   17   21
# Mexico   52   28   20
# Portugal   62   14   24
# Angola   40   27   33
# Japan   53   25   22
# Australia   61   23   16
# Czech Republic   65   19   16
# USA   58   22   20
# Ghana   40   34   26
# Italy   51   16   33
# Togo   35   43   22
# Korea Republic   42   28   30
# Switzerland   37   34   29
# France   69   10   21
# Croatia   47   19   34
# Brazil   54   19   27
# Ukraine   40   26   34
# Spain   62   14   24
# Saudi Arabia   55   24   21
# Tunisia   49   21   30
# Poland   53   27   20
# Germany   53   24   23
# Costa Rica   45   35   20
# Ecuador   36   39   25
# Trinidad and Tobago   42   42   16
# England   53   19   28
# Paraguay   39   30   31
# Sweden   44   22   34
# Serbia and Montenegro   0   0   0
# Argentina   60   18   22
# Côte dIvoire   0   0   0
# Netherlands   56   11   33
# Angola   40   27   33
# Mexico   52   28   20
# IR Iran   62   17   21
# Portugal   62   14   24
# Ghana   40   34   26
# Czech Republic   65   19   16
# USA   58   22   20
# Italy   51   16   33
# Croatia   47   19   34
# Japan   53   25   22
# Australia   61   23   16
# Brazil   54   19   27
# Korea Republic   42   28   30
# France   69   10   21
# Switzerland   37   34   29
# Togo   35   43   22
# Ukraine   40   26   34
# Saudi Arabia   55   24   21
# Tunisia   49   21   30
# Spain   62   14   24
# Germany   53   24   23
# Ecuador   36   39   25
# Poland   53   27   20
# Costa Rica   45   35   20
# England   53   19   28
# Sweden   44   22   34
# Trinidad and Tobago   42   42   16
# Paraguay   39   30   31
# Angola   40   27   33
# IR Iran   62   17   21
# Mexico   52   28   20
# Portugal   62   14   24
# Argentina   60   18   22
# Netherlands   56   11   33
# Serbia and Montenegro   0   0   0
# Côte dIvoire   0   0   0
# Italy   51   16   33
# Czech Republic   65   19   16
# USA   58   22   20
# Ghana   40   34   26
# Brazil   54   19   27
# Japan   53   25   22
# Australia   61   23   16
# Croatia   47   19   34
# Tunisia   49   21   30
# Ukraine   40   26   34
# Spain   62   14   24
# Saudi Arabia   55   24   21
# France   69   10   21
# Togo   35   43   22
# Korea Republic   42   28   30
# Switzerland   37   34   29
# Sweden   44   22   34
# Germany   53   24   23
# Mexico   52   28   20
# Argentina   60   18   22
# Ecuador   36   39   25
# England   53   19   28
# Netherlands   56   11   33
# Portugal   62   14   24
# Australia   61   23   16
# Italy   51   16   33
# Ukraine   40   26   34
# Switzerland   37   34   29
# Ghana   40   34   26
# Brazil   54   19   27
# France   69   10   21
# Spain   62   14   24
# Argentina   60   18   22
# Germany   53   24   23
# Ukraine   40   26   34
# Italy   51   16   33
# Portugal   62   14   24
# England   53   19   28
# France   69   10   21
# Brazil   54   19   27
# Italy   51   16   33
# Germany   53   24   23
# France   69   10   21
# Portugal   62   14   24
# Portugal   62   14   24
# Germany   53   24   23
# France   69   10   21
# Italy   51   16   33
# Senegal   40   27   33
# France   63   11   26
# Denmark   54   21   25
# Uruguay   40   35   25
# Cameroon   45   24   31
# Republic of Ireland   0   0   0
# Saudi Arabia   56   23   21
# Germany   59   17   24
# Nigeria   49   21   30
# Argentina   56   18   26
# South Africa   47   26   27
# Paraguay   43   30   27
# Sweden   47   20   33
# England   46   19   35
# Slovenia   32   31   27
# Spain   63   11   26
# Turkey   44   32   24
# Brazil   66   17   17
# Ecuador   41   34   25
# Italy   55   18   27
# Mexico   49   29   22
# Croatia   48   18   34
# Costa Rica   43   30   27
# China   50   26   24
# Belgium   46   28   26
# Japan   48   25   27
# Poland   40   33   27
# Korea Republic   46   19   35
# Tunisia   48   26   26
# Russia   51   21   28
# Portugal   56   16   28
# USA   48   27   25
# Republic of Ireland   0   0   0
# Germany   59   17   24
# Senegal   40   27   33
# Denmark   54   21   25
# Saudi Arabia   56   23   21
# Cameroon   45   24   31
# Uruguay   40   35   25
# France   63   11   26
# Nigeria   49   21   30
# Sweden   47   20   33
# England   46   19   35
# Argentina   56   18   26
# Paraguay   43   30   27
# Spain   63   11   26
# Slovenia   32   31   27
# South Africa   47   26   27
# China   50   26   24
# Brazil   66   17   17
# Croatia   48   18   34
# Italy   55   18   27
# Turkey   44   32   24
# Costa Rica   43   30   27
# Russia   51   21   28
# Japan   48   25   27
# Ecuador   41   34   25
# Mexico   49   29   22
# USA   48   27   25
# Korea Republic   46   19   35
# Poland   40   33   27
# Portugal   56   16   28
# Belgium   46   28   26
# Tunisia   48   26   26
# France   63   11   26
# Denmark   54   21   25
# Uruguay   40   35   25
# Senegal   40   27   33
# Republic of Ireland   0   0   0
# Saudi Arabia   56   23   21
# Germany   59   17   24
# Cameroon   45   24   31
# Argentina   56   18   26
# Sweden   47   20   33
# England   46   19   35
# Nigeria   49   21   30
# Paraguay   43   30   27
# Slovenia   32   31   27
# Spain   63   11   26
# South Africa   47   26   27
# Brazil   66   17   17
# Costa Rica   43   30   27
# China   50   26   24
# Turkey   44   32   24
# Croatia   48   18   34
# Ecuador   41   34   25
# Italy   55   18   27
# Mexico   49   29   22
# Japan   48   25   27
# Tunisia   48   26   26
# Korea Republic   46   19   35
# Portugal   56   16   28
# USA   48   27   25
# Poland   40   33   27
# Russia   51   21   28
# Belgium   46   28   26
# England   46   19   35
# Denmark   54   21   25
# Paraguay   43   30   27
# Germany   59   17   24
# Republic of Ireland   0   0   0
# Spain   63   11   26
# Senegal   40   27   33
# Sweden   47   20   33
# Belgium   46   28   26
# Brazil   66   17   17
# USA   48   27   25
# Mexico   49   29   22
# Turkey   44   32   24
# Japan   48   25   27
# Italy   55   18   27
# Korea Republic   46   19   35
# Brazil   66   17   17
# England   46   19   35
# USA   48   27   25
# Germany   59   17   24
# Turkey   44   32   24
# Senegal   40   27   33
# Korea Republic   46   19   35
# Spain   63   11   26
# Korea Republic   46   19   35
# Germany   59   17   24
# Turkey   44   32   24
# Brazil   66   17   17
# Turkey   44   32   24
# Korea Republic   46   19   35
# Brazil   66   17   17
# Germany   59   17   24
# Scotland   44   30   26
# Brazil   69   9   22
# Norway   48   20   32
# Morocco   51   18   31
# Chile   43   33   24
# Italy   57   15   28
# Austria   38   39   23
# Cameroon   40   27   33
# Bulgaria   41   34   25
# Paraguay   44   32   24
# Denmark   50   23   27
# Saudi Arabia   52   24   24
# South Africa   45   27   19
# France   55   13   32
# Nigeria   44   28   28
# Spain   56   18   26
# Mexico   45   25   30
# Korea Republic   48   22   30
# Belgium   45   28   27
# Netherlands   57   20   23
# Japan   50   27   23
# Argentina   49   17   34
# IR Iran   49   23   28
# Yugoslavia   54   28   18
# Croatia   39   14   17
# Jamaica   48   24   28
# Tunisia   48   23   29
# England   51   14   35
# Colombia   42   23   35
# Romania   53   24   23
# USA   41   32   27
# Germany   64   12   24
# Norway   48   20   32
# Scotland   44   30   26
# Morocco   51   18   31
# Brazil   69   9   22
# Austria   38   39   23
# Chile   43   33   24
# Cameroon   40   27   33
# Italy   57   15   28
# Denmark   50   23   27
# South Africa   45   27   19
# Saudi Arabia   52   24   24
# France   55   13   32
# Bulgaria   41   34   25
# Nigeria   44   28   28
# Paraguay   44   32   24
# Spain   56   18   26
# Croatia   39   14   17
# Japan   50   27   23
# Mexico   45   25   30
# Belgium   45   28   27
# Korea Republic   48   22   30
# Netherlands   57   20   23
# Yugoslavia   54   28   18
# Germany   64   12   24
# Jamaica   48   24   28
# Argentina   49   17   34
# IR Iran   49   23   28
# USA   41   32   27
# Tunisia   48   23   29
# Colombia   42   23   35
# England   51   14   35
# Romania   53   24   23
# Austria   38   39   23
# Italy   57   15   28
# Cameroon   40   27   33
# Chile   43   33   24
# Morocco   51   18   31
# Scotland   44   30   26
# Norway   48   20   32
# Brazil   69   9   22
# Denmark   50   23   27
# France   55   13   32
# Saudi Arabia   52   24   24
# South Africa   45   27   19
# Bulgaria   41   34   25
# Spain   56   18   26
# Paraguay   44   32   24
# Nigeria   44   28   28
# Korea Republic   48   22   30
# Belgium   45   28   27
# Mexico   45   25   30
# Netherlands   57   20   23
# IR Iran   49   23   28
# Germany   64   12   24
# Yugoslavia   54   28   18
# USA   41   32   27
# Jamaica   48   24   28
# Japan   50   27   23
# Croatia   39   14   17
# Argentina   49   17   34
# Tunisia   48   23   29
# Romania   53   24   23
# England   51   14   35
# Colombia   42   23   35
# Norway   48   20   32
# Italy   57   15   28
# Chile   43   33   24
# Brazil   69   9   22
# Paraguay   44   32   24
# France   55   13   32
# Denmark   50   23   27
# Nigeria   44   28   28
# Mexico   45   25   30
# Germany   64   12   24
# Yugoslavia   54   28   18
# Netherlands   57   20   23
# Croatia   39   14   17
# Romania   53   24   23
# England   51   14   35
# Argentina   49   17   34
# France   55   13   32
# Italy   57   15   28
# Denmark   50   23   27
# Brazil   69   9   22
# Argentina   49   17   34
# Netherlands   57   20   23
# Croatia   39   14   17
# Germany   64   12   24
# Netherlands   57   20   23
# Brazil   69   9   22
# Croatia   39   14   17
# France   55   13   32
# Croatia   39   14   17
# Netherlands   57   20   23
# France   55   13   32
# Brazil   69   9   22
# Korea Republic   53   16   31
# Spain   54   23   23
# Bolivia   22   50   28
# Germany   56   18   26
# Switzerland   42   30   28
# USA   32   38   30
# Republic of Ireland   0   0   0
# Italy   56   18   26
# Romania   49   24   27
# Colombia   47   20   33
# Morocco   39   24   37
# Belgium   45   30   25
# Mexico   52   20   28
# Norway   38   31   31
# Sweden   54   22   24
# Cameroon   46   21   33
# Saudi Arabia   46   27   27
# Netherlands   55   21   24
# Russia   49   20   31
# Brazil   57   15   28
# Greece   38   34   28
# Argentina   38   24   38
# Bulgaria   39   33   28
# Nigeria   45   23   32
# Spain   54   23   23
# Germany   56   18   26
# Switzerland   42   30   28
# Romania   49   24   27
# Colombia   47   20   33
# USA   32   38   30
# Norway   38   31   31
# Italy   56   18   26
# Bolivia   22   50   28
# Korea Republic   53   16   31
# Republic of Ireland   0   0   0
# Mexico   52   20   28
# Russia   49   20   31
# Sweden   54   22   24
# Cameroon   46   21   33
# Brazil   57   15   28
# Netherlands   55   21   24
# Belgium   45   30   25
# Morocco   39   24   37
# Saudi Arabia   46   27   27
# Nigeria   45   23   32
# Argentina   38   24   38
# Greece   38   34   28
# Bulgaria   39   33   28
# Romania   49   24   27
# USA   32   38   30
# Colombia   47   20   33
# Switzerland   42   30   28
# Korea Republic   53   16   31
# Germany   56   18   26
# Spain   54   23   23
# Bolivia   22   50   28
# Norway   38   31   31
# Republic of Ireland   0   0   0
# Sweden   54   22   24
# Brazil   57   15   28
# Mexico   52   20   28
# Italy   56   18   26
# Cameroon   46   21   33
# Russia   49   20   31
# Netherlands   55   21   24
# Morocco   39   24   37
# Saudi Arabia   46   27   27
# Belgium   45   30   25
# Nigeria   45   23   32
# Greece   38   34   28
# Bulgaria   39   33   28
# Argentina   38   24   38
# Belgium   45   30   25
# Germany   56   18   26
# Switzerland   42   30   28
# Spain   54   23   23
# Sweden   54   22   24
# Saudi Arabia   46   27   27
# Argentina   38   24   38
# Romania   49   24   27
# Republic of Ireland   0   0   0
# Netherlands   55   21   24
# USA   32   38   30
# Brazil   57   15   28
# Italy   56   18   26
# Nigeria   45   23   32
# Bulgaria   39   33   28
# Mexico   52   20   28
# Spain   54   23   23
# Italy   56   18   26
# Brazil   57   15   28
# Netherlands   55   21   24
# Germany   56   18   26
# Bulgaria   39   33   28
# Sweden   54   22   24
# Romania   49   24   27
# Italy   56   18   26
# Bulgaria   39   33   28
# Brazil   57   15   28
# Sweden   54   22   24
# Bulgaria   39   33   28
# Sweden   54   22   24
# Italy   56   18   26
# Brazil   57   15   28
# Korea Republic   58   20   22
# Spain   50   25   25
# Romania   42   29   29
# Russia   54   20   26
# Colombia   39   33   28
# United Arab Emirates   42   35   23
# Republic of Ireland   0   0   0
# Italy   50   20   30
# Czech Republic   42   30   28
# USA   33   39   28
# Sweden   50   26   24
# Brazil   58   15   27
# Yugoslavia   52   29   19
# Germany   57   19   24
# Scotland   40   34   26
# Costa Rica   36   27   37
# Saudi Arabia   41   31   28
# Netherlands   52   28   20
# Korea Republic   58   20   22
# Belgium   44   30   26
# Egypt   41   28   31
# Netherlands   52   28   20
# Spain   50   25   25
# Uruguay   51   20   29
# Russia   54   20   26
# Argentina   34   29   37
# Romania   42   29   29
# Cameroon   49   22   29
# Colombia   39   33   28
# Yugoslavia   52   29   19
# USA   33   39   28
# Italy   50   20   30
# Bolivia   20   60   20
# Korea Republic   58   20   22
# Republic of Ireland   0   0   0
# Mexico   57   17   26
# Costa Rica   36   27   37
# Brazil   58   15   27
# Scotland   40   34   26
# Sweden   50   26   24
# Netherlands   52   28   20
# England   51   19   30
# Morocco   40   25   35
# Saudi Arabia   41   31   28
# Spain   50   25   25
# Korea Republic   58   20   22
# Uruguay   51   20   29
# Belgium   44   30   26
# Romania   42   29   29
# Argentina   34   29   37
# Russia   54   20   26
# Cameroon   49   22   29
# Korea Republic   58   20   22
# Germany   57   19   24
# United Arab Emirates   42   35   23
# Yugoslavia   52   29   19
# Norway   32   39   29
# Republic of Ireland   0   0   0
# USA   33   39   28
# Austria   41   33   26
# Scotland   40   34   26
# Brazil   58   15   27
# Costa Rica   36   27   37
# Sweden   50   26   24
# Uruguay   51   20   29
# Korea Republic   58   20   22
# Saudi Arabia   41   31   28
# Belgium   44   30   26
# Netherlands   52   28   20
# Republic of Ireland   0   0   0
# Egypt   41   28   31
# England   51   19   30
# Colombia   39   33   28
# Cameroon   49   22   29
# Costa Rica   36   27   37
# Czech Republic   42   30   28
# Sweden   50   26   24
# Saudi Arabia   41   31   28
# Netherlands   52   28   20
# Germany   57   19   24
# Republic of Ireland   0   0   0
# Netherlands   52   28   20
# Uruguay   51   20   29
# Italy   50   20   30
# Yugoslavia   52   29   19
# Spain   50   25   25
# Belgium   44   30   26
# England   51   19   30
# Argentina   34   29   37
# Yugoslavia   52   29   19
# Republic of Ireland   0   0   0
# Italy   50   20   30
# Czech Republic   42   30   28
# Germany   57   19   24
# Cameroon   49   22   29
# England   51   19   30
# Argentina   34   29   37
# Italy   50   20   30
# Czech Republic   42   30   28
# Germany   57   19   24
# England   51   19   30
# Italy   50   20   30
# Argentina   34   29   37
# Germany   57   19   24

# %% [markdown]
# # Team Feature

# %%
features=[]
for key in df_teams.keys():
    features.append(str(key))

features

del features[0:4]

features

# %%
df_teams_avg = df_teams.groupby(['Year','team'])['goals_z'].sum()/df_teams.groupby(['Year','team'])['goals_z'].size()
df_teams_avg = df_teams_avg.to_frame()

df_teams_avg['Year'] = df_teams_avg.index.get_level_values(0).tolist()
df_teams_avg['team'] = df_teams_avg.index.get_level_values(1).tolist()


df_teams_avg.head()

# %%
def avg_team(feature,df_teams_avg):
    a=df_teams.groupby(['Year','team'])[feature].sum()/df_teams.groupby(['Year','team'])[feature].size()
    b=a.to_frame()
    df_teams_avg[feature]= b[feature]
    

for feature in features:
    avg_team(feature,df_teams_avg)

df_teams_avg.head()

# %%
new_df = pd.merge(df, df_teams_avg,  how='left', left_on=['Team1','Year'], right_on = ['team','Year'])
new_df1 = pd.merge(new_df,df_teams_avg ,  how='left', left_on=['Team2','Year'], right_on = ['team','Year'])


new_df1.head()

# %%
df = new_df1
df.isnull().sum()

# %%
df = df.dropna(axis=0, subset=['goals_z_x','goals_z_y'])
df.isnull().sum()

# %%
df.head()

# %% [markdown]
# # Add lenth of name for each country

# %%
df.to_csv("./temp.csv")

# %%
df = pd.read_csv("./temp.csv")

# %%
len_Team1 =[]
len_Team2 =[]

for i in range (len(df['Team1'])):
    len_Team1.append(len(df['Team1'][i]))
    len_Team2.append(len(df['Team2'][i]))
    
df['len_Team1'] =len_Team1
df['len_Team2'] = len_Team2

df.head()

# %% [markdown]
# # Add the Continent

# %%
continent = continent.drop_duplicates()
df['Team1'] = df['Team1'].str.strip()
df['Team2'] = df['Team2'].str.strip()

continent['name'] = continent['name'].str.strip()
continent['Continent'] = continent['Continent'].str.strip()

# %%
df.loc[df.Year >= 1990,'continent_Team1'] = df['Team1'].map(continent.set_index('name')['Continent'])
df.loc[df.Year >= 1990,'continent_Team2'] = df['Team2'].map(continent.set_index('name')['Continent'])

# %%
df.head()
# Out:
#       Team1         Team2       Rounds   Year_com   Day  Month    Year  \
# 0    Russia  Saudi Arabia  Group Phase  2018-6-14  14.0    6.0  2018.0
# 1     Egypt       Uruguay  Group Phase  2018-6-15  15.0    6.0  2018.0
# 2   Morocco       IR Iran  Group Phase  2018-6-15  15.0    6.0  2018.0
# 3  Portugal         Spain  Group Phase  2018-6-15  15.0    6.0  2018.0
# 4    France     Australia  Group Phase  2018-6-16  16.0    6.0  2018.0
#
#    Score1  Score2  Ranking T1       ...        Ranking T2  Score T2  NW1  NF1  \
# 0     5.0     0.0        70.0       ...              67.0     465.0   48   25
# 1     0.0     1.0        45.0       ...              14.0    1018.0   62   24
# 2     0.0     1.0        41.0       ...              37.0     708.0   43   26
# 3     3.0     3.0         4.0       ...              10.0    1126.0   62   18
# 4     2.0     1.0         7.0       ...              36.0     718.0   59   20
#
#    ND1  NW2  NF2  ND2  continent_Team1 continent_Team2
# 0   27   41   36   23               EU              AS
# 1   14   46   26   28               AF              SA
# 2   31   63   14   23               AF              AS
# 3   20   72   13   15               EU              EU
# 4   21   50   26   24               EU              OC
#
# [5 rows x 21 columns]

# %%
# df["Rounds"] = df["Rounds"].cat.codes
# df["Rounds"] = df["Rounds"].astype('category')

# %%
# AF = Africa
# AS = Asia
# EU = Europe
# NA = North America
# SA = South America
# OC = Oceania
# AN = Antarctica

continent_dict = {"AF":1, "AS":2, "EU":3, "OC":4, "NA":5, "SA":6, "AN":7}
continent_encoded_team1 = []
continent_encoded_team2 = []


for i in range(len(df.continent_Team1)):
    continent_encoded_team1.append(continent_dict[list(df.continent_Team1)[i]])
    continent_encoded_team2.append(continent_dict[list(df.continent_Team2)[i]])
    
df["continent_en_team1"] = continent_encoded_team1
df["continent_en_team2"] = continent_encoded_team2

df = df.drop(['continent_Team1','continent_Team2'], axis =1)

# %%
df.head()
# Out:
#       Team1         Team2       Rounds   Year_com   Day  Month    Year  \
# 0    Russia  Saudi Arabia  Group Phase  2018-6-14  14.0    6.0  2018.0
# 1     Egypt       Uruguay  Group Phase  2018-6-15  15.0    6.0  2018.0
# 2   Morocco       IR Iran  Group Phase  2018-6-15  15.0    6.0  2018.0
# 3  Portugal         Spain  Group Phase  2018-6-15  15.0    6.0  2018.0
# 4    France     Australia  Group Phase  2018-6-16  16.0    6.0  2018.0
#
#    Score1  Score2  Ranking T1         ...          Ranking T2  Score T2  NW1  \
# 0     5.0     0.0        70.0         ...                67.0     465.0   48
# 1     0.0     1.0        45.0         ...                14.0    1018.0   62
# 2     0.0     1.0        41.0         ...                37.0     708.0   43
# 3     3.0     3.0         4.0         ...                10.0    1126.0   62
# 4     2.0     1.0         7.0         ...                36.0     718.0   59
#
#    NF1  ND1  NW2  NF2  ND2  continent_en_team1  continent_en_team2
# 0   25   27   41   36   23                   3                   2
# 1   24   14   46   26   28                   1                   6
# 2   26   31   63   14   23                   1                   2
# 3   18   20   72   13   15                   3                   3
# 4   20   21   50   26   24                   3                   4
#
# [5 rows x 21 columns]

# %%
df.isnull().sum()

# %% [markdown]
# # Add winner

# %%
#Adding who is the winner 
winner = []
Winner = []
for i in range (len(df['Team1'])):
    if df['Score1'][i] > df['Score2'][i]:
        winner.append(df['Team1'][i])
        Winner.append(1)
    elif df['Score1'][i] < df['Score2'][i]:
        winner.append(df['Team2'][i])
        Winner.append(2)
    else:
        winner.append('-1')
        Winner.append(0)

df['winner'] = winner
df['Winner'] = Winner
df.head()
# Out:
#       Team1         Team2       Rounds   Year_com   Day  Month    Year  \
# 0    Russia  Saudi Arabia  Group Phase  2018-6-14  14.0    6.0  2018.0
# 1     Egypt       Uruguay  Group Phase  2018-6-15  15.0    6.0  2018.0
# 2   Morocco       IR Iran  Group Phase  2018-6-15  15.0    6.0  2018.0
# 3  Portugal         Spain  Group Phase  2018-6-15  15.0    6.0  2018.0
# 4    France     Australia  Group Phase  2018-6-16  16.0    6.0  2018.0
#
#    Score1  Score2  Ranking T1   ...    NW1  NF1  ND1  NW2  NF2  ND2  \
# 0     5.0     0.0        70.0   ...     48   25   27   41   36   23
# 1     0.0     1.0        45.0   ...     62   24   14   46   26   28
# 2     0.0     1.0        41.0   ...     43   26   31   63   14   23
# 3     3.0     3.0         4.0   ...     62   18   20   72   13   15
# 4     2.0     1.0         7.0   ...     59   20   21   50   26   24
#
#    continent_en_team1  continent_en_team2   winner  Winner
# 0                   3                   2   Russia       1
# 1                   1                   6  Uruguay       2
# 2                   1                   2  IR Iran       2
# 3                   3                   3       -1       0
# 4                   3                   4   France       1
#
# [5 rows x 23 columns]

# %%
winner_counter = []
team1_winning=[]
team2_winning=[]

team1_winning_complete=[]
team2_winning_complete=[]


for i in range(len(df['Team1'])):
    if i != 0: 
        if df['Year'][i] != df['Year'][i-1]:
            for x in team1_winning:
                team1_winning_complete.append(x)
            for y in team2_winning:
                team2_winning_complete.append(y)


            winner_counter = []
            team1_winning=[]
            team2_winning=[]
            
    
        if ((df['winner'][i] != -1) & (df['winner'][i] == df['Team1'][i])):

            team2_winning.append(winner_counter.count(df['Team2'][i]))
            team1_winning.append(winner_counter.count(df['Team1'][i]))

            winner_counter.append(df['Team1'][i])

        elif((df['winner'][i] != -1) & (df['winner'][i] == df['Team2'][i])):

            team1_winning.append(winner_counter.count(df['Team1'][i]))
            team2_winning.append( winner_counter.count(df['Team2'][i]))


            winner_counter.append(df['Team2'][i])

        else:
            team1_winning.append(winner_counter.count(df['Team1'][i]))
            team2_winning.append(winner_counter.count(df['Team2'][i]))

    else:
        team1_winning.append(0)
        team2_winning.append(0)

        

for x in team1_winning:
    team1_winning_complete.append(x)
for y in team2_winning:
    team2_winning_complete.append(y)

   
    
            
df['team1_winning'] = team1_winning_complete
df['team2_winning'] = team2_winning_complete

# %%
df.shape

# %%
df.head()

# %% [markdown]
# # Encode Country

# %%
countries = list(set(df["Team1"]).union(set(df["Team2"])))
countries_dict = {}
for i in range(len(countries)):
    countries_dict[countries[i]] = i
    
Team1_encoded = []
Team2_encoded = []

for i in range(len(df)):
    Team1_encoded.append(countries_dict[list(df.Team1)[i]])
    Team2_encoded.append(countries_dict[list(df.Team2)[i]])
    
df["Team1"] = Team1_encoded
df["Team2"] = Team2_encoded

# %%
df.head()
# Out:
#    Team1  Team2       Rounds   Year_com   Day  Month    Year  Score1  Score2  \
# 0     54     15  Group Phase  2018-6-14  14.0    6.0  2018.0     5.0     0.0
# 1     65     36  Group Phase  2018-6-15  15.0    6.0  2018.0     0.0     1.0
# 2      9     58  Group Phase  2018-6-15  15.0    6.0  2018.0     0.0     1.0
# 3     27     59  Group Phase  2018-6-15  15.0    6.0  2018.0     3.0     3.0
# 4     18     42  Group Phase  2018-6-16  16.0    6.0  2018.0     2.0     1.0
#
#    Ranking T1   ...    NW1  NF1  ND1  NW2  NF2  ND2  continent_en_team1  \
# 0        70.0   ...     48   25   27   41   36   23                   3
# 1        45.0   ...     62   24   14   46   26   28                   1
# 2        41.0   ...     43   26   31   63   14   23                   1
# 3         4.0   ...     62   18   20   72   13   15                   3
# 4         7.0   ...     59   20   21   50   26   24                   3
#
#    continent_en_team2   winner  Winner
# 0                   2   Russia       1
# 1                   6  Uruguay       2
# 2                   2  IR Iran       2
# 3                   3       -1       0
# 4                   4   France       1
#
# [5 rows x 23 columns]

# %%
df = df.drop(['Score1','Score2','winner'], axis= 1)

# %%
# rounds = df.Rounds
# rounds.unique()
# rounds_dict = {"Group Phase":1, "Round of 16":2, "Quarter Finals":3, "Semi Finals":4, "Play-off for third place":5, "Finals":6}
# rounds_encoded = []

# for i in range(len(df)):
#     rounds_encoded.append(rounds_dict[list(df.Rounds)[i]])
    
# df["Rounds"] = rounds_encoded

# %%
# df = df.drop(['team_x','team_y'],axis=1)

# %%
df = df.drop(['Unnamed: 0','Score1','Score2','winner'], axis =1)
# df = df.drop(['Unnamed: 0','Score1','Score2','team_x','team_y','winner'], axis =1)

# %%
df.head()
# Out:
#    Team1  Team2       Rounds   Year_com   Day  Month    Year  Ranking T1  \
# 0     54     15  Group Phase  2018-6-14  14.0    6.0  2018.0        70.0
# 1     65     36  Group Phase  2018-6-15  15.0    6.0  2018.0        45.0
# 2      9     58  Group Phase  2018-6-15  15.0    6.0  2018.0        41.0
# 3     27     59  Group Phase  2018-6-15  15.0    6.0  2018.0         4.0
# 4     18     42  Group Phase  2018-6-16  16.0    6.0  2018.0         7.0
#
#    Score T1  Ranking T2  Score T2  NW1  NF1  ND1  NW2  NF2  ND2  \
# 0     457.0        67.0     465.0   48   25   27   41   36   23
# 1     649.0        14.0    1018.0   62   24   14   46   26   28
# 2     686.0        37.0     708.0   43   26   31   63   14   23
# 3    1274.0        10.0    1126.0   62   18   20   72   13   15
# 4    1198.0        36.0     718.0   59   20   21   50   26   24
#
#    continent_en_team1  continent_en_team2  Winner
# 0                   3                   2       1
# 1                   1                   6       2
# 2                   1                   2       2
# 3                   3                   3       0
# 4                   3                   4       1

# %%
df = df.drop(['Rounds'], axis =1)

# %%
import category_encoders as ce
df =ce.OneHotEncoder(cols=['Team1','Team2','Rounds','continent_Team1','continent_Team2']).fit_transform(df,df['Winner'])

# %%
df.head()
# Out:
#    Team1  Team2       Rounds    Year  Ranking T1  Score T1  Ranking T2  \
# 0     54     15  Group Phase  2018.0        70.0     457.0        67.0
# 1     65     36  Group Phase  2018.0        45.0     649.0        14.0
# 2      9     58  Group Phase  2018.0        41.0     686.0        37.0
# 3     27     59  Group Phase  2018.0         4.0    1274.0        10.0
# 4     18     42  Group Phase  2018.0         7.0    1198.0        36.0
#
#    Score T2  NW1  NF1  ND1  NW2  NF2  ND2  continent_en_team1  \
# 0     465.0   48   25   27   41   36   23                   3
# 1    1018.0   62   24   14   46   26   28                   1
# 2     708.0   43   26   31   63   14   23                   1
# 3    1126.0   62   18   20   72   13   15                   3
# 4     718.0   59   20   21   50   26   24                   3
#
#    continent_en_team2  Winner
# 0                   2       1
# 1                   6       2
# 2                   2       2
# 3                   3       0
# 4                   4       1

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
# y = df['Winner']
# df = df.drop(['Winner'], axis =1)
# header_name =list(X_train.columns.values)
# print(header_name)
sfs1 = SFS(neigh, 
           k_features=10, 
           forward=True, 
           floating=False, 
           verbose=2,
           scoring='accuracy',
           cv=0)

sfs1 = sfs1.fit(X_train,y_train)

# %%
sfs1.k_feature_idx_

# %%
for i in list(sfs1.k_feature_idx_):
    print(header_name[i])

# %%
df = df[['Year','Team1_10','Team1_29','Team2_10','Team2_29','Rounds_5','goals_z_x','progruns_z_y','blocks_z_y','fouled_z_y','team1_winning','Winner']]

# %%
df.head()
# Out:
#    Team1  Team2    Year  Ranking T1  Score T1  Ranking T2  Score T2  NW1  NF1  \
# 0     54     15  2018.0        70.0     457.0        67.0     465.0   48   25
# 1     65     36  2018.0        45.0     649.0        14.0    1018.0   62   24
# 2      9     58  2018.0        41.0     686.0        37.0     708.0   43   26
# 3     27     59  2018.0         4.0    1274.0        10.0    1126.0   62   18
# 4     18     42  2018.0         7.0    1198.0        36.0     718.0   59   20
#
#    ND1  NW2  NF2  ND2  continent_en_team1  continent_en_team2  Winner
# 0   27   41   36   23                   3                   2       1
# 1   14   46   26   28                   1                   6       2
# 2   31   63   14   23                   1                   2       2
# 3   20   72   13   15                   3                   3       0
# 4   21   50   26   24                   3                   4       1

# %%
sfs1.k_score_

# %%
df = df.drop(['Year_com','Day','Month'],axis=1)

# %%
for c in df.keys():
    print(c)

# %% [markdown]
# # Train & test

# %%
X_train = df.loc[(df['Year']!= 2018)]
X_test  = df.loc[(df['Year'] == 2018)]

y_train =  X_train["Winner"]
y_test  =  X_test["Winner"]

X_train = X_train.drop(['Winner'],axis=1)
X_test = X_test.drop(['Winner'],axis=1)

# X_train = X_train.drop(['Winner','team_x','team_y'],axis=1)
# X_test = X_test.drop(['Winner','team_x','team_y'],axis=1)

# %%
for c in X_train.keys():
    print(c)
# Out:
# Team1
# Team2
# Year
# Ranking T1
# Score T1
# Ranking T2
# Score T2
# NW1
# NF1
# ND1
# NW2
# NF2
# ND2
# continent_en_team1
# continent_en_team2

# %%
df.head()

# %%
X_train = X_train.drop(['Ranking T1','Ranking T2'],axis=1)
X_test = X_test.drop(['Ranking T1','Ranking T2'],axis=1)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (848, 13)
# (128, 13)

# %%
from sklearn.svm import SVC
from sklearn.datasets import load_digits
from sklearn.feature_selection import RFE
import matplotlib.pyplot as plt

# Create the RFE object and rank each pixel
svc = SVC(kernel="linear", C=1)
rfe = RFE(estimator=svc, n_features_to_select=11, step=1)
X_new =rfe.fit(df, df['Winner'])

X_new.shape

# %%
X_test.iloc[0]

# %%
X_test.head()

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()  
X_train = sc.fit_transform(X_train)  
X_test = sc.transform(X_test) 


import xgboost as xgb

dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

import xgboost as xgb
from sklearn.datasets import dump_svmlight_file

dump_svmlight_file(X_train, y_train, 'dtrain.svm', zero_based=True)
dump_svmlight_file(X_test, y_test, 'dtest.svm', zero_based=True)
dtrain_svm = xgb.DMatrix('dtrain.svm')
dtest_svm = xgb.DMatrix('dtest.svm')
# Out:
# [00:30:33] 848x13 matrix with 11024 entries loaded from dtrain.svm
# [00:30:33] 128x13 matrix with 1664 entries loaded from dtest.svm

# %%
param = {
    'max_depth': 50,  # the maximum depth of each tree
    'eta': 0.005,  # the training step for each iteration
    'silent': 1,  # logging mode - quiet
    'objective': 'multi:softprob',  # error evaluation for multiclass training
    'num_class': 69}  # the number of classes that exist in this datset
num_round = 1000  # the number of training iterations

# %%
bst = xgb.train(param, dtrain, num_round)
preds = bst.predict(dtest)

import numpy as np
best_preds = np.asarray([np.argmax(line) for line in preds])


from sklearn.metrics import precision_score

print(accuracy_score(y_test, best_preds))
# Out:
# 0.546875

# %%
from sklearn import svm
model_svm = svm.SVC()
model_svm.fit(X_train,y_train)

y_pred_svm = model_svm.predict(X_test)


accuracy_score(y_test, y_pred_svm)
# Out:
# 0.515625

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=5)
neigh.fit(X_train, y_train) 
y_pred_neigh = neigh.predict(X_test)
accuracy_score(y_test, y_pred_neigh)
# Out:
# 0.4921875

# %%
model_svm.predict([[-1.88311701,  1.73369565,  0.29386772, -0.49299277,  1.96755193,
       -0.18129363, -0.16239592,  1.49092911, -0.63904823, -0.16016975,
       -0.35151564, -1.05590009, -0.25826668, -0.81182324, -0.57273967,
       -1.18318577, -0.40759521,  1.19900457, -0.49516943,  2.90417344,
        1.78662061, -0.74060623, -0.03438443, -1.12279921, -0.47668739,
       -0.08327925, -1.63341844,  0.7866811 , -0.28311076, -0.6396246 ,
        0.20268982,  1.42660544,  0.32660141, -1.22817515,  0.89398111,
       -2.10535758, -1.532413  ,  0.19244285, -1.21486428, -0.56510533,
        1.66210323, -0.27490465, -0.90994275, -0.74932094, -0.74932094]])

# %%
model_svm.predict([[1.73369565,-1.88311701, 0.29386772, -0.49299277, 
       1.96755193,-0.18129363,  -0.03438443, -1.12279921, -0.47668739,
       -0.08327925, -1.63341844,  0.7866811 , -0.28311076, -0.6396246 ,
        0.20268982,  1.42660544,-0.16239592,  1.49092911, -0.63904823, -0.16016975,
       -0.35151564, -1.05590009, -0.25826668, -0.81182324, -0.57273967,
       -1.18318577, -0.40759521,  1.19900457, -0.49516943,  2.90417344,
        1.78662061, -0.74060623,-1.22817515,0.32660141,0.89398111,
       -2.10535758, -1.532413  ,  0.19244285, -1.21486428, -0.56510533,
        1.66210323,-0.90994275,-0.27490465,-0.74932094, -0.74932094]])

# %%
for ii in range(len(y_pred_svm)):
    if y_pred_svm[ii] != y_test[ii]:
        print(y_pred_svm[ii],"  ",y_test[ii])

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

model= DecisionTreeClassifier()
model.fit(X_train,y_train)

y_pred = model.predict(X_test)

accuracy_score(y_test, y_pred)

# %%
model = Sequential()
model.add(Dense(12, input_dim=X_train.shape[1], activation='sigmoid'))
model.add(Dense(8, activation='sigmoid'))
#model.dropout()
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy']) #categorical crossentropy?

hist = model.fit(X_train, y_train, validation_data=(X_test,y_test), shuffle=True, epochs=100, batch_size=2)

# %%
scores = model.evaluate(X_test, y_test)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

model_inf = ExtraTreesClassifier()
model_inf.fit(X_train, y_train)

model_tree= DecisionTreeClassifier()
model_tree.fit(X_train,y_train)

y_pred_tree = model_tree.predict(X_test)

print(accuracy_score(y_test, y_pred_tree))


information_gain = {}

for i in range(len(model_inf.feature_importances_)):
    information_gain.update({i: model_inf.feature_importances_[i]})
    
    
for key in information_gain: 
    print(key,information_gain[key])

# %%
X_train
